# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'automobile': 1, 'cat': 3, 'bird': 2, 'airplane': 0, 'truck': 9, 'deer': 4, 'dog': 5, 'ship': 8, 'frog': 6, 'horse': 7}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [20535 27908  6547 ...,  8446 32716 13669]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary2'
iteration = 20000
batch_size = 128
learning_rate = 0.003

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=32, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1')
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=pool1, filters=64, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv2')
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
#     with tf.name_scope('conv3') as scope:
#         conv3 = tf.layers.conv2d(inputs=pool2, filters=128, kernel_size=3, strides=1, 
#                             padding = 'SAME', activation = tf.nn.relu, name='conv3')
#         batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
#         pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2, padding='SAME', name='pool3')

    with tf.name_scope('fc') as scope:
        pool3_flat = tf.reshape(pool2, [-1, 8*8*64], name='pool3_flat')
#         dropout1 = tf.layers.dropout(pool3_flat, rate=dropout_rate, training=training, name='dropout1')
#         dense1 = tf.layers.dense(pool3_flat, units = 8*128, activation = tf.nn.relu, name='dense1')
#         batch_norm4 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm4')
#         dropout2 = tf.layers.dropout(dense1, rate=dropout_rate, training=training, name='dropout2')
        dense2 = tf.layers.dense(pool3_flat, units = 128, activation = tf.nn.relu, name='dense2')
#         dropout3 = tf.layers.dropout(dense2, rate=dropout_rate, training=training, name='dropout3')
        batch_norm5 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm5')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(batch_norm5, units = 10, name='logits')

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    with tf.name_scope('summary') as scope:
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
        return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.32546, the accuracy is 0.091
# training! after 0 iterations the loss is 2.29668, the accuracy is 0.117188
# ###################################
# validation! after 100 iterations the loss is 2.28628, the accuracy is 0.1346
# training! after 100 iterations the loss is 2.27831, the accuracy is 0.164062
# ###################################
# validation! after 200 iterations the loss is 2.27042, the accuracy is 0.1602
# training! after 200 iterations the loss is 2.27304, the accuracy is 0.15625
# ###################################
# validation! after 300 iterations the loss is 2.25487, the accuracy is 0.1814
# training! after 300 iterations the loss is 2.25637, the accuracy is 0.203125
# ###################################
# validation! after 400 iterations the loss is 2.2349, the accuracy is 0.202
# training! after 400 iterations the loss is 2.22594, the accuracy is 0.21875
# ###################################
# validation! after 500 iterations the loss is 2.21256, the accuracy is 0.2136
# training! after 500 iterations the loss is 2.21344, the accuracy is 0.21875
# ###################################
# validation! after 600 iterations the loss is 2.18111, the accuracy is 0.2524
# training! after 600 iterations the loss is 2.18921, the accuracy is 0.1875
# ###################################
# validation! after 700 iterations the loss is 2.14429, the accuracy is 0.251
# training! after 700 iterations the loss is 2.10679, the accuracy is 0.28125
# ###################################
# validation! after 800 iterations the loss is 2.10627, the accuracy is 0.2616
# training! after 800 iterations the loss is 2.13829, the accuracy is 0.265625
# ###################################
# validation! after 900 iterations the loss is 2.07071, the accuracy is 0.2668
# training! after 900 iterations the loss is 2.12284, the accuracy is 0.21875
# ###################################
# validation! after 1000 iterations the loss is 2.04026, the accuracy is 0.2826
# training! after 1000 iterations the loss is 2.01946, the accuracy is 0.304688
# ###################################
# validation! after 1100 iterations the loss is 2.00625, the accuracy is 0.2986
# training! after 1100 iterations the loss is 2.02702, the accuracy is 0.265625
# ###################################
# validation! after 1200 iterations the loss is 1.98737, the accuracy is 0.3022
# training! after 1200 iterations the loss is 1.96895, the accuracy is 0.3125
# ###################################
# validation! after 1300 iterations the loss is 1.96012, the accuracy is 0.319
# training! after 1300 iterations the loss is 1.90394, the accuracy is 0.335938
# ###################################
# validation! after 1400 iterations the loss is 1.95626, the accuracy is 0.3088
# training! after 1400 iterations the loss is 1.96517, the accuracy is 0.28125
# ###################################
# validation! after 1500 iterations the loss is 1.93161, the accuracy is 0.317
# training! after 1500 iterations the loss is 1.98506, the accuracy is 0.328125
# ###################################
# validation! after 1600 iterations the loss is 1.9147, the accuracy is 0.3182
# training! after 1600 iterations the loss is 1.87193, the accuracy is 0.359375
# ###################################
# validation! after 1700 iterations the loss is 1.90403, the accuracy is 0.323
# training! after 1700 iterations the loss is 1.93442, the accuracy is 0.359375
# ###################################
# validation! after 1800 iterations the loss is 1.88691, the accuracy is 0.3364
# training! after 1800 iterations the loss is 1.8339, the accuracy is 0.351562
# ###################################
# validation! after 1900 iterations the loss is 1.88353, the accuracy is 0.3364
# training! after 1900 iterations the loss is 1.78921, the accuracy is 0.4375
# ###################################
# validation! after 2000 iterations the loss is 1.86988, the accuracy is 0.3476
# training! after 2000 iterations the loss is 1.94727, the accuracy is 0.296875
# ###################################
# validation! after 2100 iterations the loss is 1.84999, the accuracy is 0.3528
# training! after 2100 iterations the loss is 1.82336, the accuracy is 0.375
# ###################################
# validation! after 2200 iterations the loss is 1.83932, the accuracy is 0.3618
# training! after 2200 iterations the loss is 1.81838, the accuracy is 0.4375
# ###################################
# validation! after 2300 iterations the loss is 1.82777, the accuracy is 0.3608
# training! after 2300 iterations the loss is 1.66912, the accuracy is 0.445312
# ###################################
# validation! after 2400 iterations the loss is 1.82067, the accuracy is 0.3648
# training! after 2400 iterations the loss is 1.73433, the accuracy is 0.414062
# ###################################
# validation! after 2500 iterations the loss is 1.80991, the accuracy is 0.3698
# training! after 2500 iterations the loss is 1.70056, the accuracy is 0.421875
# ###################################
# validation! after 2600 iterations the loss is 1.7937, the accuracy is 0.3772
# training! after 2600 iterations the loss is 1.77914, the accuracy is 0.429688
# ###################################
# validation! after 2700 iterations the loss is 1.78557, the accuracy is 0.3822
# training! after 2700 iterations the loss is 1.87193, the accuracy is 0.375
# ###################################
# validation! after 2800 iterations the loss is 1.77641, the accuracy is 0.37
# training! after 2800 iterations the loss is 1.76533, the accuracy is 0.398438
# ###################################
# validation! after 2900 iterations the loss is 1.77188, the accuracy is 0.3762
# training! after 2900 iterations the loss is 1.75579, the accuracy is 0.375
# ###################################
# validation! after 3000 iterations the loss is 1.75775, the accuracy is 0.3914
# training! after 3000 iterations the loss is 1.62219, the accuracy is 0.453125
# ###################################
# validation! after 3100 iterations the loss is 1.7356, the accuracy is 0.3956
# training! after 3100 iterations the loss is 1.75017, the accuracy is 0.382812
# ###################################
# validation! after 3200 iterations the loss is 1.73002, the accuracy is 0.3962
# training! after 3200 iterations the loss is 1.69808, the accuracy is 0.367188
# ###################################
# validation! after 3300 iterations the loss is 1.72141, the accuracy is 0.3944
# training! after 3300 iterations the loss is 1.56966, the accuracy is 0.460938
# ###################################
# validation! after 3400 iterations the loss is 1.71157, the accuracy is 0.406
# training! after 3400 iterations the loss is 1.72116, the accuracy is 0.40625
# ###################################
# validation! after 3500 iterations the loss is 1.69978, the accuracy is 0.4012
# training! after 3500 iterations the loss is 1.69854, the accuracy is 0.390625
# ###################################
# validation! after 3600 iterations the loss is 1.68542, the accuracy is 0.414
# training! after 3600 iterations the loss is 1.58963, the accuracy is 0.414062
# ###################################
# validation! after 3700 iterations the loss is 1.67768, the accuracy is 0.4118
# training! after 3700 iterations the loss is 1.67565, the accuracy is 0.421875
# ###################################
# validation! after 3800 iterations the loss is 1.66756, the accuracy is 0.4166
# training! after 3800 iterations the loss is 1.61043, the accuracy is 0.429688
# ###################################
# validation! after 3900 iterations the loss is 1.64284, the accuracy is 0.4304
# training! after 3900 iterations the loss is 1.7176, the accuracy is 0.40625
# ###################################
# validation! after 4000 iterations the loss is 1.64446, the accuracy is 0.417
# training! after 4000 iterations the loss is 1.53305, the accuracy is 0.445312
# ###################################
# validation! after 4100 iterations the loss is 1.63013, the accuracy is 0.426
# training! after 4100 iterations the loss is 1.59303, the accuracy is 0.414062
# ###################################
# validation! after 4200 iterations the loss is 1.61944, the accuracy is 0.4354
# training! after 4200 iterations the loss is 1.61162, the accuracy is 0.5
# ###################################
# validation! after 4300 iterations the loss is 1.62054, the accuracy is 0.4208
# training! after 4300 iterations the loss is 1.45602, the accuracy is 0.515625
# ###################################
# validation! after 4400 iterations the loss is 1.59557, the accuracy is 0.4402
# training! after 4400 iterations the loss is 1.56203, the accuracy is 0.476562
# ###################################
# validation! after 4500 iterations the loss is 1.60185, the accuracy is 0.4358
# training! after 4500 iterations the loss is 1.46677, the accuracy is 0.484375
# ###################################
# validation! after 4600 iterations the loss is 1.60399, the accuracy is 0.4256
# training! after 4600 iterations the loss is 1.57729, the accuracy is 0.5
# ###################################
# validation! after 4700 iterations the loss is 1.60953, the accuracy is 0.4226
# training! after 4700 iterations the loss is 1.51761, the accuracy is 0.523438
# ###################################
# validation! after 4800 iterations the loss is 1.59778, the accuracy is 0.4324
# training! after 4800 iterations the loss is 1.38563, the accuracy is 0.492188
# ###################################
# validation! after 4900 iterations the loss is 1.59297, the accuracy is 0.437
# training! after 4900 iterations the loss is 1.69199, the accuracy is 0.359375
# ###################################
# validation! after 5000 iterations the loss is 1.57223, the accuracy is 0.4448
# training! after 5000 iterations the loss is 1.38863, the accuracy is 0.492188
# ###################################
# validation! after 5100 iterations the loss is 1.5471, the accuracy is 0.4568
# training! after 5100 iterations the loss is 1.60683, the accuracy is 0.453125
# ###################################
# validation! after 5200 iterations the loss is 1.54524, the accuracy is 0.4592
# training! after 5200 iterations the loss is 1.38813, the accuracy is 0.5
# ###################################
# validation! after 5300 iterations the loss is 1.53193, the accuracy is 0.4648
# training! after 5300 iterations the loss is 1.23237, the accuracy is 0.59375
# ###################################
# validation! after 5400 iterations the loss is 1.54531, the accuracy is 0.453
# training! after 5400 iterations the loss is 1.50353, the accuracy is 0.484375
# ###################################
# validation! after 5500 iterations the loss is 1.51737, the accuracy is 0.464
# training! after 5500 iterations the loss is 1.39965, the accuracy is 0.515625
# ###################################
# validation! after 5600 iterations the loss is 1.51758, the accuracy is 0.464
# training! after 5600 iterations the loss is 1.55912, the accuracy is 0.421875
# ###################################
# validation! after 5700 iterations the loss is 1.562, the accuracy is 0.4524
# training! after 5700 iterations the loss is 1.39183, the accuracy is 0.476562
# ###################################
# validation! after 5800 iterations the loss is 1.49441, the accuracy is 0.4726
# training! after 5800 iterations the loss is 1.60316, the accuracy is 0.476562
# ###################################
# validation! after 5900 iterations the loss is 1.53113, the accuracy is 0.4606
# training! after 5900 iterations the loss is 1.42333, the accuracy is 0.484375
# ###################################
# validation! after 6000 iterations the loss is 1.48263, the accuracy is 0.4784
# training! after 6000 iterations the loss is 1.43035, the accuracy is 0.515625
# ###################################
# validation! after 6100 iterations the loss is 1.4933, the accuracy is 0.4664
# training! after 6100 iterations the loss is 1.33433, the accuracy is 0.507812
# ###################################
# validation! after 6200 iterations the loss is 1.50654, the accuracy is 0.4686
# training! after 6200 iterations the loss is 1.21897, the accuracy is 0.609375
# ###################################
# validation! after 6300 iterations the loss is 1.50208, the accuracy is 0.4694
# training! after 6300 iterations the loss is 1.52109, the accuracy is 0.453125
# ###################################
# validation! after 6400 iterations the loss is 1.46387, the accuracy is 0.4766
# training! after 6400 iterations the loss is 1.32691, the accuracy is 0.515625
# ###################################
# validation! after 6500 iterations the loss is 1.52217, the accuracy is 0.4594
# training! after 6500 iterations the loss is 1.41487, the accuracy is 0.492188
# ###################################
# validation! after 6600 iterations the loss is 1.46128, the accuracy is 0.4744
# training! after 6600 iterations the loss is 1.20572, the accuracy is 0.578125
# ###################################
# validation! after 6700 iterations the loss is 1.43712, the accuracy is 0.4912
# training! after 6700 iterations the loss is 1.36001, the accuracy is 0.453125
# ###################################
# validation! after 6800 iterations the loss is 1.46987, the accuracy is 0.4754
# training! after 6800 iterations the loss is 1.41865, the accuracy is 0.460938
# ###################################
# validation! after 6900 iterations the loss is 1.43106, the accuracy is 0.4982
# training! after 6900 iterations the loss is 1.33187, the accuracy is 0.554688
# ###################################
# validation! after 7000 iterations the loss is 1.43965, the accuracy is 0.4932
# training! after 7000 iterations the loss is 1.33784, the accuracy is 0.554688
# ###################################
# validation! after 7100 iterations the loss is 1.43905, the accuracy is 0.4852
# training! after 7100 iterations the loss is 1.45857, the accuracy is 0.476562
# ###################################
# validation! after 7200 iterations the loss is 1.42383, the accuracy is 0.4944
# training! after 7200 iterations the loss is 1.34898, the accuracy is 0.515625
# ###################################
# validation! after 7300 iterations the loss is 1.41429, the accuracy is 0.5018
# training! after 7300 iterations the loss is 1.34931, the accuracy is 0.515625
# ###################################
# validation! after 7400 iterations the loss is 1.42262, the accuracy is 0.5028
# training! after 7400 iterations the loss is 1.28897, the accuracy is 0.570312
# ###################################
# validation! after 7500 iterations the loss is 1.40724, the accuracy is 0.5044
# training! after 7500 iterations the loss is 1.17526, the accuracy is 0.640625
# ###################################
# validation! after 7600 iterations the loss is 1.39523, the accuracy is 0.5048
# training! after 7600 iterations the loss is 1.37804, the accuracy is 0.460938
# ###################################
# validation! after 7700 iterations the loss is 1.39722, the accuracy is 0.5056
# training! after 7700 iterations the loss is 1.29375, the accuracy is 0.578125
# ###################################
# validation! after 7800 iterations the loss is 1.39019, the accuracy is 0.5128
# training! after 7800 iterations the loss is 1.44488, the accuracy is 0.515625
# ###################################
# validation! after 7900 iterations the loss is 1.39981, the accuracy is 0.5088
# training! after 7900 iterations the loss is 1.33246, the accuracy is 0.53125
# ###################################
# validation! after 8000 iterations the loss is 1.43756, the accuracy is 0.4902
# training! after 8000 iterations the loss is 1.28123, the accuracy is 0.5625
# ###################################
# validation! after 8100 iterations the loss is 1.37721, the accuracy is 0.5142
# training! after 8100 iterations the loss is 1.26869, the accuracy is 0.59375
# ###################################
# validation! after 8200 iterations the loss is 1.37035, the accuracy is 0.5154
# training! after 8200 iterations the loss is 1.19556, the accuracy is 0.617188
# ###################################
# validation! after 8300 iterations the loss is 1.38513, the accuracy is 0.513
# training! after 8300 iterations the loss is 1.20287, the accuracy is 0.515625
# ###################################
# validation! after 8400 iterations the loss is 1.35843, the accuracy is 0.523
# training! after 8400 iterations the loss is 1.34235, the accuracy is 0.523438
# ###################################
# validation! after 8500 iterations the loss is 1.36727, the accuracy is 0.5216
# training! after 8500 iterations the loss is 1.42081, the accuracy is 0.507812
# ###################################
# validation! after 8600 iterations the loss is 1.36025, the accuracy is 0.5174
# training! after 8600 iterations the loss is 1.20705, the accuracy is 0.617188
# ###################################
# validation! after 8700 iterations the loss is 1.35688, the accuracy is 0.5226
# training! after 8700 iterations the loss is 1.16555, the accuracy is 0.585938
# ###################################
# validation! after 8800 iterations the loss is 1.34572, the accuracy is 0.524
# training! after 8800 iterations the loss is 1.37892, the accuracy is 0.53125
# ###################################
# validation! after 8900 iterations the loss is 1.37198, the accuracy is 0.5214
# training! after 8900 iterations the loss is 1.38297, the accuracy is 0.546875
# ###################################
# validation! after 9000 iterations the loss is 1.36072, the accuracy is 0.5166
# training! after 9000 iterations the loss is 1.2099, the accuracy is 0.578125
# ###################################
# validation! after 9100 iterations the loss is 1.32746, the accuracy is 0.5342
# training! after 9100 iterations the loss is 1.25874, the accuracy is 0.53125
# ###################################
# validation! after 9200 iterations the loss is 1.38373, the accuracy is 0.5126
# training! after 9200 iterations the loss is 1.29245, the accuracy is 0.546875
# ###################################
# validation! after 9300 iterations the loss is 1.33348, the accuracy is 0.539
# training! after 9300 iterations the loss is 1.25987, the accuracy is 0.59375
# ###################################
# validation! after 9400 iterations the loss is 1.32758, the accuracy is 0.5324
# training! after 9400 iterations the loss is 1.13988, the accuracy is 0.601562
# ###################################
# validation! after 9500 iterations the loss is 1.32382, the accuracy is 0.53
# training! after 9500 iterations the loss is 1.22252, the accuracy is 0.5625
# ###################################
# validation! after 9600 iterations the loss is 1.31183, the accuracy is 0.5406
# training! after 9600 iterations the loss is 1.23529, the accuracy is 0.53125
# ###################################
# validation! after 9700 iterations the loss is 1.3253, the accuracy is 0.5396
# training! after 9700 iterations the loss is 1.23781, the accuracy is 0.539062
# ###################################
# validation! after 9800 iterations the loss is 1.3478, the accuracy is 0.5266
# training! after 9800 iterations the loss is 1.20363, the accuracy is 0.5625
# ###################################
# validation! after 9900 iterations the loss is 1.31527, the accuracy is 0.5314
# training! after 9900 iterations the loss is 1.11988, the accuracy is 0.617188
# ###################################
# validation! after 10000 iterations the loss is 1.3155, the accuracy is 0.5398
# training! after 10000 iterations the loss is 1.05405, the accuracy is 0.671875
# ###################################
# validation! after 10100 iterations the loss is 1.29144, the accuracy is 0.5492
# training! after 10100 iterations the loss is 1.15279, the accuracy is 0.570312
# ###################################
# validation! after 10200 iterations the loss is 1.38426, the accuracy is 0.5154
# training! after 10200 iterations the loss is 1.19615, the accuracy is 0.539062
# ###################################
# validation! after 10300 iterations the loss is 1.29967, the accuracy is 0.5502
# training! after 10300 iterations the loss is 1.24686, the accuracy is 0.507812
# ###################################
# validation! after 10400 iterations the loss is 1.30084, the accuracy is 0.5376
# training! after 10400 iterations the loss is 1.15505, the accuracy is 0.65625
# ###################################
# validation! after 10500 iterations the loss is 1.34773, the accuracy is 0.5284
# training! after 10500 iterations the loss is 1.26635, the accuracy is 0.523438
# ###################################
# validation! after 10600 iterations the loss is 1.30059, the accuracy is 0.545
# training! after 10600 iterations the loss is 1.1029, the accuracy is 0.640625
# ###################################
# validation! after 10700 iterations the loss is 1.27751, the accuracy is 0.5538
# training! after 10700 iterations the loss is 1.21497, the accuracy is 0.570312
# ###################################
# validation! after 10800 iterations the loss is 1.2932, the accuracy is 0.5456
# training! after 10800 iterations the loss is 1.19946, the accuracy is 0.609375
# ###################################
# validation! after 10900 iterations the loss is 1.27333, the accuracy is 0.5618
# training! after 10900 iterations the loss is 1.19182, the accuracy is 0.609375
# ###################################
# validation! after 11000 iterations the loss is 1.2811, the accuracy is 0.5496
# training! after 11000 iterations the loss is 1.2651, the accuracy is 0.578125
# ###################################
# validation! after 11100 iterations the loss is 1.27925, the accuracy is 0.5496
# training! after 11100 iterations the loss is 1.11949, the accuracy is 0.65625
# ###################################
# validation! after 11200 iterations the loss is 1.28591, the accuracy is 0.5542
# training! after 11200 iterations the loss is 1.13416, the accuracy is 0.632812
# ###################################
# validation! after 11300 iterations the loss is 1.27577, the accuracy is 0.5556
# training! after 11300 iterations the loss is 1.21066, the accuracy is 0.601562
# ###################################
# validation! after 11400 iterations the loss is 1.25306, the accuracy is 0.556
# training! after 11400 iterations the loss is 1.15751, the accuracy is 0.59375
# ###################################
# validation! after 11500 iterations the loss is 1.26304, the accuracy is 0.5578
# training! after 11500 iterations the loss is 1.05961, the accuracy is 0.632812
# ###################################
# validation! after 11600 iterations the loss is 1.26965, the accuracy is 0.565
# training! after 11600 iterations the loss is 1.02139, the accuracy is 0.632812
# ###################################
# validation! after 11700 iterations the loss is 1.26255, the accuracy is 0.5584
# training! after 11700 iterations the loss is 1.16746, the accuracy is 0.578125
# ###################################
# validation! after 11800 iterations the loss is 1.25151, the accuracy is 0.5612
# training! after 11800 iterations the loss is 1.10844, the accuracy is 0.609375
# ###################################
# validation! after 11900 iterations the loss is 1.24876, the accuracy is 0.5636
# training! after 11900 iterations the loss is 1.15062, the accuracy is 0.585938
# ###################################
# validation! after 12000 iterations the loss is 1.25909, the accuracy is 0.5654
# training! after 12000 iterations the loss is 1.17049, the accuracy is 0.5625
# ###################################
# validation! after 12100 iterations the loss is 1.25313, the accuracy is 0.5588
# training! after 12100 iterations the loss is 1.02989, the accuracy is 0.59375
# ###################################
# validation! after 12200 iterations the loss is 1.24064, the accuracy is 0.5702
# training! after 12200 iterations the loss is 1.34377, the accuracy is 0.539062
# ###################################
# validation! after 12300 iterations the loss is 1.23522, the accuracy is 0.5706
# training! after 12300 iterations the loss is 1.19382, the accuracy is 0.570312
# ###################################
# validation! after 12400 iterations the loss is 1.25501, the accuracy is 0.5634
# training! after 12400 iterations the loss is 1.13258, the accuracy is 0.585938
# ###################################
# validation! after 12500 iterations the loss is 1.23409, the accuracy is 0.5672
# training! after 12500 iterations the loss is 0.997186, the accuracy is 0.671875
# ###################################
# validation! after 12600 iterations the loss is 1.24625, the accuracy is 0.5684
# training! after 12600 iterations the loss is 1.13555, the accuracy is 0.625
# ###################################
# validation! after 12700 iterations the loss is 1.23489, the accuracy is 0.569
# training! after 12700 iterations the loss is 0.968358, the accuracy is 0.6875
# ###################################
# validation! after 12800 iterations the loss is 1.24002, the accuracy is 0.5684
# training! after 12800 iterations the loss is 1.12016, the accuracy is 0.59375
# ###################################
# validation! after 12900 iterations the loss is 1.26059, the accuracy is 0.5574
# training! after 12900 iterations the loss is 1.07256, the accuracy is 0.59375
# ###################################
# validation! after 13000 iterations the loss is 1.23391, the accuracy is 0.5654
# training! after 13000 iterations the loss is 1.19624, the accuracy is 0.632812
# ###################################
# validation! after 13100 iterations the loss is 1.21927, the accuracy is 0.5768
# training! after 13100 iterations the loss is 1.17783, the accuracy is 0.570312
# ###################################
# validation! after 13200 iterations the loss is 1.22222, the accuracy is 0.5726
# training! after 13200 iterations the loss is 1.11741, the accuracy is 0.625
# ###################################
# validation! after 13300 iterations the loss is 1.22739, the accuracy is 0.5702
# training! after 13300 iterations the loss is 0.957627, the accuracy is 0.671875
# ###################################
# validation! after 13400 iterations the loss is 1.24193, the accuracy is 0.569
# training! after 13400 iterations the loss is 1.243, the accuracy is 0.585938
# ###################################
# validation! after 13500 iterations the loss is 1.22593, the accuracy is 0.57
# training! after 13500 iterations the loss is 1.19637, the accuracy is 0.578125
# ###################################
# validation! after 13600 iterations the loss is 1.23716, the accuracy is 0.5722
# training! after 13600 iterations the loss is 1.04503, the accuracy is 0.632812
# ###################################
# validation! after 13700 iterations the loss is 1.22839, the accuracy is 0.578
# training! after 13700 iterations the loss is 1.07303, the accuracy is 0.59375
# ###################################
# validation! after 13800 iterations the loss is 1.24492, the accuracy is 0.569
# training! after 13800 iterations the loss is 1.15833, the accuracy is 0.601562
# ###################################
# validation! after 13900 iterations the loss is 1.23262, the accuracy is 0.5662
# training! after 13900 iterations the loss is 1.26369, the accuracy is 0.585938
# ###################################
# validation! after 14000 iterations the loss is 1.20442, the accuracy is 0.5732
# training! after 14000 iterations the loss is 1.09478, the accuracy is 0.617188
# ###################################
# validation! after 14100 iterations the loss is 1.20454, the accuracy is 0.5796
# training! after 14100 iterations the loss is 1.06481, the accuracy is 0.625
# ###################################
# validation! after 14200 iterations the loss is 1.20761, the accuracy is 0.5754
# training! after 14200 iterations the loss is 1.02981, the accuracy is 0.632812
# ###################################
# validation! after 14300 iterations the loss is 1.19777, the accuracy is 0.5792
# training! after 14300 iterations the loss is 1.02606, the accuracy is 0.65625
# ###################################
# validation! after 14400 iterations the loss is 1.1933, the accuracy is 0.5842
# training! after 14400 iterations the loss is 0.994258, the accuracy is 0.6875
# ###################################
# validation! after 14500 iterations the loss is 1.1922, the accuracy is 0.5834
# training! after 14500 iterations the loss is 1.0121, the accuracy is 0.648438
# ###################################
# validation! after 14600 iterations the loss is 1.1883, the accuracy is 0.5866
# training! after 14600 iterations the loss is 1.11444, the accuracy is 0.59375
# ###################################
# validation! after 14700 iterations the loss is 1.20658, the accuracy is 0.5796
# training! after 14700 iterations the loss is 1.10363, the accuracy is 0.648438
# ###################################
# validation! after 14800 iterations the loss is 1.19462, the accuracy is 0.5888
# training! after 14800 iterations the loss is 1.10218, the accuracy is 0.632812
# ###################################
# validation! after 14900 iterations the loss is 1.19271, the accuracy is 0.5904
# training! after 14900 iterations the loss is 1.27272, the accuracy is 0.5625
# ###################################
# validation! after 15000 iterations the loss is 1.18001, the accuracy is 0.5872
# training! after 15000 iterations the loss is 0.944803, the accuracy is 0.6875
# ###################################
# validation! after 15100 iterations the loss is 1.18217, the accuracy is 0.589
# training! after 15100 iterations the loss is 0.906227, the accuracy is 0.703125
# ###################################
# validation! after 15200 iterations the loss is 1.20874, the accuracy is 0.585
# training! after 15200 iterations the loss is 1.02839, the accuracy is 0.679688
# ###################################
# validation! after 15300 iterations the loss is 1.17759, the accuracy is 0.5842
# training! after 15300 iterations the loss is 1.01496, the accuracy is 0.679688
# ###################################
# validation! after 15400 iterations the loss is 1.18767, the accuracy is 0.5874
# training! after 15400 iterations the loss is 1.02271, the accuracy is 0.640625
# ###################################
# validation! after 15500 iterations the loss is 1.17265, the accuracy is 0.5908
# training! after 15500 iterations the loss is 1.25287, the accuracy is 0.640625
# ###################################
# validation! after 15600 iterations the loss is 1.17368, the accuracy is 0.5972
# training! after 15600 iterations the loss is 1.01444, the accuracy is 0.640625
# ###################################
# validation! after 15700 iterations the loss is 1.1798, the accuracy is 0.592
# training! after 15700 iterations the loss is 1.01663, the accuracy is 0.664062
# ###################################
# validation! after 15800 iterations the loss is 1.17706, the accuracy is 0.5866
# training! after 15800 iterations the loss is 0.930632, the accuracy is 0.65625
# ###################################
# validation! after 15900 iterations the loss is 1.17976, the accuracy is 0.5866
# training! after 15900 iterations the loss is 1.04277, the accuracy is 0.625
# ###################################
# validation! after 16000 iterations the loss is 1.16671, the accuracy is 0.5908
# training! after 16000 iterations the loss is 0.95698, the accuracy is 0.6875
# ###################################
# validation! after 16100 iterations the loss is 1.20286, the accuracy is 0.5824
# training! after 16100 iterations the loss is 1.23658, the accuracy is 0.554688
# ###################################
# validation! after 16200 iterations the loss is 1.18024, the accuracy is 0.588
# training! after 16200 iterations the loss is 0.951326, the accuracy is 0.65625
# ###################################
# validation! after 16300 iterations the loss is 1.17104, the accuracy is 0.602
# training! after 16300 iterations the loss is 1.05496, the accuracy is 0.671875
# ###################################
# validation! after 16400 iterations the loss is 1.1864, the accuracy is 0.5816
# training! after 16400 iterations the loss is 0.910346, the accuracy is 0.679688
# ###################################
# validation! after 16500 iterations the loss is 1.16185, the accuracy is 0.5986
# training! after 16500 iterations the loss is 0.980498, the accuracy is 0.679688
# ###################################
# validation! after 16600 iterations the loss is 1.18188, the accuracy is 0.5926
# training! after 16600 iterations the loss is 0.989336, the accuracy is 0.601562
# ###################################
# validation! after 16700 iterations the loss is 1.15063, the accuracy is 0.5964
# training! after 16700 iterations the loss is 0.854629, the accuracy is 0.679688
# ###################################
# validation! after 16800 iterations the loss is 1.14615, the accuracy is 0.6052
# training! after 16800 iterations the loss is 1.02349, the accuracy is 0.625
# ###################################
# validation! after 16900 iterations the loss is 1.14482, the accuracy is 0.6022
# training! after 16900 iterations the loss is 1.0601, the accuracy is 0.585938
# ###################################
# validation! after 17000 iterations the loss is 1.17681, the accuracy is 0.5876
# training! after 17000 iterations the loss is 1.01438, the accuracy is 0.65625
# ###################################
# validation! after 17100 iterations the loss is 1.1537, the accuracy is 0.5982
# training! after 17100 iterations the loss is 0.916091, the accuracy is 0.695312
# ###################################
# validation! after 17200 iterations the loss is 1.14965, the accuracy is 0.6006
# training! after 17200 iterations the loss is 0.841672, the accuracy is 0.734375
# ###################################
# validation! after 17300 iterations the loss is 1.13855, the accuracy is 0.6064
# training! after 17300 iterations the loss is 0.806905, the accuracy is 0.734375
# ###################################
# validation! after 17400 iterations the loss is 1.16564, the accuracy is 0.5952
# training! after 17400 iterations the loss is 0.850154, the accuracy is 0.734375
# ###################################
# validation! after 17500 iterations the loss is 1.13299, the accuracy is 0.6076
# training! after 17500 iterations the loss is 0.867397, the accuracy is 0.703125
# ###################################
# validation! after 17600 iterations the loss is 1.13532, the accuracy is 0.6106
# training! after 17600 iterations the loss is 0.886498, the accuracy is 0.710938
# ###################################
# validation! after 17700 iterations the loss is 1.12333, the accuracy is 0.6136
# training! after 17700 iterations the loss is 0.949753, the accuracy is 0.679688
# ###################################
# validation! after 17800 iterations the loss is 1.14685, the accuracy is 0.5986
# training! after 17800 iterations the loss is 0.939976, the accuracy is 0.664062
# ###################################
# validation! after 17900 iterations the loss is 1.13081, the accuracy is 0.6146
# training! after 17900 iterations the loss is 1.06732, the accuracy is 0.617188
# ###################################
# validation! after 18000 iterations the loss is 1.13556, the accuracy is 0.604
# training! after 18000 iterations the loss is 0.819762, the accuracy is 0.742188
# ###################################
# validation! after 18100 iterations the loss is 1.14777, the accuracy is 0.603
# training! after 18100 iterations the loss is 1.08895, the accuracy is 0.65625
# ###################################
# validation! after 18200 iterations the loss is 1.12162, the accuracy is 0.611
# training! after 18200 iterations the loss is 0.9512, the accuracy is 0.648438
# ###################################
# validation! after 18300 iterations the loss is 1.12517, the accuracy is 0.6132
# training! after 18300 iterations the loss is 0.909699, the accuracy is 0.710938
# ###################################
# validation! after 18400 iterations the loss is 1.11825, the accuracy is 0.617
# training! after 18400 iterations the loss is 1.08911, the accuracy is 0.648438
# ###################################
# validation! after 18500 iterations the loss is 1.16096, the accuracy is 0.592
# training! after 18500 iterations the loss is 1.05334, the accuracy is 0.664062
# ###################################
# validation! after 18600 iterations the loss is 1.13924, the accuracy is 0.5954
# training! after 18600 iterations the loss is 0.934564, the accuracy is 0.671875
# ###################################
# validation! after 18700 iterations the loss is 1.13255, the accuracy is 0.6082
# training! after 18700 iterations the loss is 0.941086, the accuracy is 0.703125
# ###################################
# validation! after 18800 iterations the loss is 1.13528, the accuracy is 0.6072
# training! after 18800 iterations the loss is 0.8747, the accuracy is 0.6875
# ###################################
# validation! after 18900 iterations the loss is 1.12528, the accuracy is 0.6032
# training! after 18900 iterations the loss is 0.820667, the accuracy is 0.71875
# ###################################
# validation! after 19000 iterations the loss is 1.14154, the accuracy is 0.6054
# training! after 19000 iterations the loss is 0.90532, the accuracy is 0.648438
# ###################################
# validation! after 19100 iterations the loss is 1.13155, the accuracy is 0.6058
# training! after 19100 iterations the loss is 0.882604, the accuracy is 0.671875
# ###################################
# validation! after 19200 iterations the loss is 1.12592, the accuracy is 0.6114
# training! after 19200 iterations the loss is 0.888432, the accuracy is 0.679688
# ###################################
# validation! after 19300 iterations the loss is 1.13697, the accuracy is 0.6082
# training! after 19300 iterations the loss is 1.00798, the accuracy is 0.609375
# ###################################
# validation! after 19400 iterations the loss is 1.11926, the accuracy is 0.61
# training! after 19400 iterations the loss is 0.886361, the accuracy is 0.703125
# ###################################
# validation! after 19500 iterations the loss is 1.1074, the accuracy is 0.6182
# training! after 19500 iterations the loss is 0.826343, the accuracy is 0.734375
# ###################################
# validation! after 19600 iterations the loss is 1.10404, the accuracy is 0.6196
# training! after 19600 iterations the loss is 0.940957, the accuracy is 0.640625
# ###################################
# validation! after 19700 iterations the loss is 1.11424, the accuracy is 0.6142
# training! after 19700 iterations the loss is 0.999687, the accuracy is 0.640625
# ###################################
# validation! after 19800 iterations the loss is 1.13147, the accuracy is 0.6024
# training! after 19800 iterations the loss is 0.881507, the accuracy is 0.695312
# ###################################
# validation! after 19900 iterations the loss is 1.09944, the accuracy is 0.619
# training! after 19900 iterations the loss is 0.852636, the accuracy is 0.726562

# %%
save_predictions('ans1-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
# Out:
# (10, 10000)
# array([[-0.32845241,  5.18926954,  3.284199  , ..., -2.08364224,
#          1.89161623, -1.9955827 ],
#        [-0.92231286,  6.81710529, -1.40714264, ..., -4.23306036,
#          2.67013192, -2.12823343],
#        [ 1.29318702, -1.24278831,  1.11408091, ...,  4.63280296,
#          0.17653756,  0.77820146],
#        ...,
#        [ 0.17517456, -5.27479744, -1.9035852 , ...,  2.24026823,
#         -1.48832309,  4.12482548],
#        [ 0.6478706 ,  8.37031269,  2.21339464, ...,  0.69101042,
#         -2.07646132, -1.8791436 ],
#        [-2.21827674,  4.69626665, -2.77827787, ..., -3.03447771,
#         -0.1140641 , -0.62013012]], dtype=float32)
