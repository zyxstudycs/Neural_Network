# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'bird': 2, 'deer': 4, 'ship': 8, 'automobile': 1, 'horse': 7, 'frog': 6, 'cat': 3, 'dog': 5, 'truck': 9, 'airplane': 0}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [44659 14074 26648 ...,  7643 38151 18444]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary_resNet2'
iteration = 10000
batch_size = 128
learning_rate = 0.001

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
regularizer = tf.contrib.layers.l2_regularizer(scale=0.1)
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1',
                                kernel_regularizer = regularizer)
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1,rate=0.3, training=training, name='dropout1')
#         pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=dropout1, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv2',
                                kernel_regularizer = regularizer)
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        combine2 = tf.add(batch_norm1, batch_norm2, name='combine2')
        dropout2 = tf.layers.dropout(combine2,rate=0.4, training=training, name='dropout2')
        
#         pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=dropout2, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv3',
                                kernel_regularizer = regularizer)
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        
        batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
        combine3 = tf.add(batch_norm3, combine2, name='combine3')
#         dropout3 = tf.layers.dropout(combine3, rate=0.4, training=training, name='dropout3')
        pool3 = tf.layers.max_pooling2d(inputs=combine3, pool_size=2, strides=2, padding='SAME', name='pool3')
        
    with tf.name_scope('conv4') as scope:
        conv4 = tf.layers.conv2d(inputs=pool3, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv4',
                                kernel_regularizer = regularizer)
        weight4= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv4')[0]
        
        batch_norm4 = tf.layers.batch_normalization(conv4, axis = 1, name='batch_norm4')
        combine4 = tf.add(pool3, batch_norm4, name='combine4')
        dropout4 = tf.layers.dropout(combine4,rate=0.4, training=training, name='dropout4')
#         pool4 = tf.layers.max_pooling2d(inputs=batch_norm4, pool_size=2, strides=2, padding='SAME', name='pool4')

    with tf.name_scope('conv5') as scope:
        conv5 = tf.layers.conv2d(inputs=dropout4, filters=128, kernel_size=3, strides=2, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv5',
                                kernel_regularizer = regularizer)
        weight5= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv5')[0]
        
        batch_norm5 = tf.layers.batch_normalization(conv5, axis = 1, name='batch_norm5')
        dropout5 = tf.layers.dropout(batch_norm5,rate=0.4, training=training, name='dropout5')
        
    with tf.name_scope('conv6') as scope:
        conv6 = tf.layers.conv2d(inputs=dropout5, filters=128, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv6',
                                kernel_regularizer = regularizer)
        weight6= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv6')[0]
        
        batch_norm6 = tf.layers.batch_normalization(conv6, axis = 1, name='batch_norm6')
        combine6 = tf.add(batch_norm5, batch_norm6, name='combine6')
#         dropout5 = tf.layers.dropout(batch_norm5,rate=0.3, training=training, name='dropout5')
        pool6 = tf.layers.max_pooling2d(inputs=combine6, pool_size=2, strides=2, padding='SAME', name='pool6')

    with tf.name_scope('conv6') as scope:
        conv7 = tf.layers.conv2d(inputs=pool6, filters=128, kernel_size=4, strides=1, 
                                padding = 'VALID', activation = tf.nn.relu, name='conv7',
                                kernel_regularizer = regularizer)
        weight7= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv7')[0]
        
        batch_norm7 = tf.layers.batch_normalization(conv7, axis = 1, name='batch_norm7')
#         combine6 = tf.add(batch_norm5, batch_norm6, name='combine6')
#         dropout5 = tf.layers.dropout(batch_norm5,rate=0.3, training=training, name='dropout5')
#         pool6 = tf.layers.max_pooling2d(inputs=combine6, pool_size=2, strides=2, padding='SAME', name='pool6')
    
    with tf.name_scope('fc') as scope:
        pool4_flat = tf.reshape(batch_norm7, [-1, 128], name='pool4_flat')
        dropout_fc1 = tf.layers.dropout(pool4_flat, rate=0.4, training=training, name='dropout_fc1')
        
        dense1 = tf.layers.dense(dropout_fc1, units = 32, activation = tf.nn.relu, name='dense1',
                                kernel_regularizer = regularizer)
        batch_norm8 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm8')
        dropout_fc2 = tf.layers.dropout(batch_norm8, rate=0.4, training=training, name='dropout_fc2')
        
#         dense2 = tf.layers.dense(dropout_fc2, units = 128, activation = tf.nn.relu, name='dense2',
#                                 kernel_regularizer = regularizer)
#         batch_norm6 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm6')
#         dropout_fc3 = tf.layers.dropout(batch_norm6, rate=0.4, training=training, name='dropout_fc3')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout_fc2, units = 10, name='logits',kernel_regularizer = regularizer)
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    
        
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight4,'weight4')
        save_variable(weight5,'weight5')
        save_variable(weight6,'weight6')
        save_variable(weight7,'weight7')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(logits)
# Out:
# Tensor("logits/logits/BiasAdd:0", shape=(?, 10), dtype=float32, device=/device:GPU:0)

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.30225, the accuracy is 0.116
# training! after 0 iterations the loss is 2.28916, the accuracy is 0.117188
# ###################################
# validation! after 100 iterations the loss is 2.22715, the accuracy is 0.162
# training! after 100 iterations the loss is 2.27497, the accuracy is 0.132812
# ###################################
# validation! after 200 iterations the loss is 1.81333, the accuracy is 0.3416
# training! after 200 iterations the loss is 1.78382, the accuracy is 0.34375
# ###################################
# validation! after 300 iterations the loss is 1.51338, the accuracy is 0.4482
# training! after 300 iterations the loss is 1.51297, the accuracy is 0.421875
# ###################################
# validation! after 400 iterations the loss is 1.39219, the accuracy is 0.5006
# training! after 400 iterations the loss is 1.39728, the accuracy is 0.570312
# ###################################
# validation! after 500 iterations the loss is 1.34349, the accuracy is 0.5196
# training! after 500 iterations the loss is 1.33223, the accuracy is 0.515625
# ###################################
# validation! after 600 iterations the loss is 1.20942, the accuracy is 0.5696
# training! after 600 iterations the loss is 1.16112, the accuracy is 0.601562
# ###################################
# validation! after 700 iterations the loss is 1.14433, the accuracy is 0.5904
# training! after 700 iterations the loss is 0.841528, the accuracy is 0.6875
# ###################################
# validation! after 800 iterations the loss is 1.06124, the accuracy is 0.6202
# training! after 800 iterations the loss is 0.951064, the accuracy is 0.617188
# ###################################
# validation! after 900 iterations the loss is 1.00622, the accuracy is 0.6384
# training! after 900 iterations the loss is 1.06335, the accuracy is 0.578125
# ###################################
# validation! after 1000 iterations the loss is 0.973486, the accuracy is 0.6508
# training! after 1000 iterations the loss is 0.760426, the accuracy is 0.71875
# ###################################
# validation! after 1100 iterations the loss is 0.962717, the accuracy is 0.6592
# training! after 1100 iterations the loss is 0.867349, the accuracy is 0.65625
# ###################################
# validation! after 1200 iterations the loss is 0.923701, the accuracy is 0.6714
# training! after 1200 iterations the loss is 0.889446, the accuracy is 0.703125
# ###################################
# validation! after 1300 iterations the loss is 0.891987, the accuracy is 0.6878
# training! after 1300 iterations the loss is 0.568787, the accuracy is 0.8125
# ###################################
# validation! after 1400 iterations the loss is 0.8927, the accuracy is 0.6906
# training! after 1400 iterations the loss is 0.749137, the accuracy is 0.734375
# ###################################
# validation! after 1500 iterations the loss is 0.843728, the accuracy is 0.6958
# training! after 1500 iterations the loss is 0.68701, the accuracy is 0.765625
# ###################################
# validation! after 1600 iterations the loss is 0.878299, the accuracy is 0.6924
# training! after 1600 iterations the loss is 0.87042, the accuracy is 0.71875
# ###################################
# validation! after 1700 iterations the loss is 0.899701, the accuracy is 0.6888
# training! after 1700 iterations the loss is 0.713785, the accuracy is 0.726562
# ###################################
# validation! after 1800 iterations the loss is 0.787723, the accuracy is 0.7216
# training! after 1800 iterations the loss is 0.615284, the accuracy is 0.78125
# ###################################
# validation! after 1900 iterations the loss is 0.782496, the accuracy is 0.7304
# training! after 1900 iterations the loss is 0.641823, the accuracy is 0.796875
# ###################################
# validation! after 2000 iterations the loss is 0.781801, the accuracy is 0.726
# training! after 2000 iterations the loss is 0.639109, the accuracy is 0.796875
# ###################################
# validation! after 2100 iterations the loss is 0.749033, the accuracy is 0.7352
# training! after 2100 iterations the loss is 0.675495, the accuracy is 0.8125
# ###################################
# validation! after 2200 iterations the loss is 0.726464, the accuracy is 0.7456
# training! after 2200 iterations the loss is 0.658998, the accuracy is 0.726562
# ###################################
# validation! after 2300 iterations the loss is 0.738138, the accuracy is 0.743
# training! after 2300 iterations the loss is 0.563414, the accuracy is 0.820312
# ###################################
# validation! after 2400 iterations the loss is 0.730414, the accuracy is 0.7458
# training! after 2400 iterations the loss is 0.577388, the accuracy is 0.773438
# ###################################
# validation! after 2500 iterations the loss is 0.706866, the accuracy is 0.7572
# training! after 2500 iterations the loss is 0.708582, the accuracy is 0.71875
# ###################################
# validation! after 2600 iterations the loss is 0.752131, the accuracy is 0.7368
# training! after 2600 iterations the loss is 0.448885, the accuracy is 0.84375
# ###################################
# validation! after 2700 iterations the loss is 0.713059, the accuracy is 0.7558
# training! after 2700 iterations the loss is 0.325036, the accuracy is 0.882812
# ###################################
# validation! after 2800 iterations the loss is 0.734667, the accuracy is 0.7398
# training! after 2800 iterations the loss is 0.414482, the accuracy is 0.835938
# ###################################
# validation! after 2900 iterations the loss is 0.699243, the accuracy is 0.764
# training! after 2900 iterations the loss is 0.353991, the accuracy is 0.859375
# ###################################
# validation! after 3000 iterations the loss is 0.67749, the accuracy is 0.7662
# training! after 3000 iterations the loss is 0.588587, the accuracy is 0.789062
# ###################################
# validation! after 3100 iterations the loss is 0.703918, the accuracy is 0.7632
# training! after 3100 iterations the loss is 0.499819, the accuracy is 0.828125
# ###################################
# validation! after 3200 iterations the loss is 0.701724, the accuracy is 0.759
# training! after 3200 iterations the loss is 0.485819, the accuracy is 0.804688
# ###################################
# validation! after 3300 iterations the loss is 0.688491, the accuracy is 0.757
# training! after 3300 iterations the loss is 0.466666, the accuracy is 0.835938
# ###################################
# validation! after 3400 iterations the loss is 0.671718, the accuracy is 0.7758
# training! after 3400 iterations the loss is 0.313791, the accuracy is 0.90625
# ###################################
# validation! after 3500 iterations the loss is 0.663851, the accuracy is 0.778
# training! after 3500 iterations the loss is 0.480441, the accuracy is 0.820312
# ###################################
# validation! after 3600 iterations the loss is 0.688556, the accuracy is 0.7656
# training! after 3600 iterations the loss is 0.424099, the accuracy is 0.851562
# ###################################
# validation! after 3700 iterations the loss is 0.681942, the accuracy is 0.7744
# training! after 3700 iterations the loss is 0.375563, the accuracy is 0.882812
# ###################################
# validation! after 3800 iterations the loss is 0.654696, the accuracy is 0.7758
# training! after 3800 iterations the loss is 0.322478, the accuracy is 0.867188
# ###################################
# validation! after 3900 iterations the loss is 0.663791, the accuracy is 0.7756
# training! after 3900 iterations the loss is 0.431843, the accuracy is 0.835938
# ###################################
# validation! after 4000 iterations the loss is 0.648637, the accuracy is 0.7842
# training! after 4000 iterations the loss is 0.502558, the accuracy is 0.851562
# ###################################
# validation! after 4100 iterations the loss is 0.686122, the accuracy is 0.7748
# training! after 4100 iterations the loss is 0.483234, the accuracy is 0.835938
# ###################################
# validation! after 4200 iterations the loss is 0.632661, the accuracy is 0.7914
# training! after 4200 iterations the loss is 0.563015, the accuracy is 0.8125
# ###################################
# validation! after 4300 iterations the loss is 0.68989, the accuracy is 0.7722
# training! after 4300 iterations the loss is 0.331495, the accuracy is 0.914062
# ###################################
# validation! after 4400 iterations the loss is 0.646976, the accuracy is 0.7846
# training! after 4400 iterations the loss is 0.388795, the accuracy is 0.851562
# ###################################
# validation! after 4500 iterations the loss is 0.634836, the accuracy is 0.7836
# training! after 4500 iterations the loss is 0.319989, the accuracy is 0.867188
# ###################################
# validation! after 4600 iterations the loss is 0.651489, the accuracy is 0.784
# training! after 4600 iterations the loss is 0.542628, the accuracy is 0.835938
# ###################################
# validation! after 4700 iterations the loss is 0.639929, the accuracy is 0.7902
# training! after 4700 iterations the loss is 0.437747, the accuracy is 0.820312
# ###################################
# validation! after 4800 iterations the loss is 0.626559, the accuracy is 0.7914
# training! after 4800 iterations the loss is 0.358145, the accuracy is 0.875
# ###################################
# validation! after 4900 iterations the loss is 0.636433, the accuracy is 0.784
# training! after 4900 iterations the loss is 0.307189, the accuracy is 0.914062
# ###################################
# validation! after 5000 iterations the loss is 0.639969, the accuracy is 0.7848
# training! after 5000 iterations the loss is 0.492626, the accuracy is 0.835938
# ###################################
# validation! after 5100 iterations the loss is 0.627961, the accuracy is 0.7908
# training! after 5100 iterations the loss is 0.399267, the accuracy is 0.859375
# ###################################
# validation! after 5200 iterations the loss is 0.624648, the accuracy is 0.7956
# training! after 5200 iterations the loss is 0.511051, the accuracy is 0.796875
# ###################################
# validation! after 5300 iterations the loss is 0.621755, the accuracy is 0.7944
# training! after 5300 iterations the loss is 0.351293, the accuracy is 0.84375
# ###################################
# validation! after 5400 iterations the loss is 0.658655, the accuracy is 0.7862
# training! after 5400 iterations the loss is 0.321339, the accuracy is 0.898438
# ###################################
# validation! after 5500 iterations the loss is 0.617862, the accuracy is 0.795
# training! after 5500 iterations the loss is 0.184235, the accuracy is 0.960938
# ###################################
# validation! after 5600 iterations the loss is 0.628095, the accuracy is 0.7956
# training! after 5600 iterations the loss is 0.395781, the accuracy is 0.851562
# ###################################
# validation! after 5700 iterations the loss is 0.621391, the accuracy is 0.7952
# training! after 5700 iterations the loss is 0.442581, the accuracy is 0.867188
# ###################################
# validation! after 5800 iterations the loss is 0.631773, the accuracy is 0.7916
# training! after 5800 iterations the loss is 0.245218, the accuracy is 0.929688
# ###################################
# validation! after 5900 iterations the loss is 0.612824, the accuracy is 0.798
# training! after 5900 iterations the loss is 0.213087, the accuracy is 0.914062
# ###################################
# validation! after 6000 iterations the loss is 0.602108, the accuracy is 0.8014
# training! after 6000 iterations the loss is 0.287531, the accuracy is 0.898438
# ###################################
# validation! after 6100 iterations the loss is 0.620191, the accuracy is 0.8
# training! after 6100 iterations the loss is 0.529151, the accuracy is 0.84375
# ###################################
# validation! after 6200 iterations the loss is 0.604099, the accuracy is 0.8082
# training! after 6200 iterations the loss is 0.152026, the accuracy is 0.960938
# ###################################
# validation! after 6300 iterations the loss is 0.627835, the accuracy is 0.796
# training! after 6300 iterations the loss is 0.275303, the accuracy is 0.929688
# ###################################
# validation! after 6400 iterations the loss is 0.609806, the accuracy is 0.802
# training! after 6400 iterations the loss is 0.153188, the accuracy is 0.96875
# ###################################
# validation! after 6500 iterations the loss is 0.632164, the accuracy is 0.7946
# training! after 6500 iterations the loss is 0.228593, the accuracy is 0.929688
# ###################################
# validation! after 6600 iterations the loss is 0.652286, the accuracy is 0.7968
# training! after 6600 iterations the loss is 0.228483, the accuracy is 0.914062
# ###################################
# validation! after 6700 iterations the loss is 0.597851, the accuracy is 0.8104
# training! after 6700 iterations the loss is 0.239486, the accuracy is 0.898438
# ###################################
# validation! after 6800 iterations the loss is 0.634188, the accuracy is 0.8016
# training! after 6800 iterations the loss is 0.0884811, the accuracy is 0.984375
# ###################################
# validation! after 6900 iterations the loss is 0.600874, the accuracy is 0.8128
# training! after 6900 iterations the loss is 0.459589, the accuracy is 0.84375
# ###################################
# validation! after 7000 iterations the loss is 0.615585, the accuracy is 0.8058
# training! after 7000 iterations the loss is 0.245435, the accuracy is 0.890625
# ###################################
# validation! after 7100 iterations the loss is 0.623229, the accuracy is 0.8062
# training! after 7100 iterations the loss is 0.219375, the accuracy is 0.914062
# ###################################
# validation! after 7200 iterations the loss is 0.648338, the accuracy is 0.8038
# training! after 7200 iterations the loss is 0.448408, the accuracy is 0.859375
# ###################################
# validation! after 7300 iterations the loss is 0.62526, the accuracy is 0.8044
# training! after 7300 iterations the loss is 0.256486, the accuracy is 0.945312
# ###################################
# validation! after 7400 iterations the loss is 0.599481, the accuracy is 0.8064
# training! after 7400 iterations the loss is 0.18695, the accuracy is 0.953125
# ###################################
# validation! after 7500 iterations the loss is 0.618768, the accuracy is 0.805
# training! after 7500 iterations the loss is 0.239757, the accuracy is 0.90625
# ###################################
# validation! after 7600 iterations the loss is 0.60455, the accuracy is 0.814
# training! after 7600 iterations the loss is 0.188963, the accuracy is 0.9375
# ###################################
# validation! after 7700 iterations the loss is 0.607159, the accuracy is 0.813
# training! after 7700 iterations the loss is 0.210131, the accuracy is 0.9375
# ###################################
# validation! after 7800 iterations the loss is 0.604992, the accuracy is 0.8098
# training! after 7800 iterations the loss is 0.452337, the accuracy is 0.859375
# ###################################
# validation! after 7900 iterations the loss is 0.615006, the accuracy is 0.804
# training! after 7900 iterations the loss is 0.309299, the accuracy is 0.875
# ###################################
# validation! after 8000 iterations the loss is 0.628868, the accuracy is 0.805
# training! after 8000 iterations the loss is 0.197251, the accuracy is 0.9375
# ###################################
# validation! after 8100 iterations the loss is 0.619422, the accuracy is 0.8068
# training! after 8100 iterations the loss is 0.381307, the accuracy is 0.875
# ###################################
# validation! after 8200 iterations the loss is 0.596541, the accuracy is 0.814
# training! after 8200 iterations the loss is 0.231922, the accuracy is 0.921875
# ###################################
# validation! after 8300 iterations the loss is 0.61357, the accuracy is 0.8076
# training! after 8300 iterations the loss is 0.126664, the accuracy is 0.960938
# ###################################
# validation! after 8400 iterations the loss is 0.631525, the accuracy is 0.805
# training! after 8400 iterations the loss is 0.264279, the accuracy is 0.929688
# ###################################
# validation! after 8500 iterations the loss is 0.606783, the accuracy is 0.8156
# training! after 8500 iterations the loss is 0.157465, the accuracy is 0.9375
# ###################################
# validation! after 8600 iterations the loss is 0.587869, the accuracy is 0.8164
# training! after 8600 iterations the loss is 0.135976, the accuracy is 0.953125
# ###################################
# validation! after 8700 iterations the loss is 0.609718, the accuracy is 0.8182
# training! after 8700 iterations the loss is 0.138861, the accuracy is 0.960938
# ###################################
# validation! after 8800 iterations the loss is 0.62864, the accuracy is 0.8066
# training! after 8800 iterations the loss is 0.182583, the accuracy is 0.945312
# ###################################
# validation! after 8900 iterations the loss is 0.597214, the accuracy is 0.8134
# training! after 8900 iterations the loss is 0.364548, the accuracy is 0.828125
# ###################################
# validation! after 9000 iterations the loss is 0.597458, the accuracy is 0.8152
# training! after 9000 iterations the loss is 0.226485, the accuracy is 0.921875
# ###################################
# validation! after 9100 iterations the loss is 0.607615, the accuracy is 0.8154
# training! after 9100 iterations the loss is 0.30173, the accuracy is 0.890625
# ###################################
# validation! after 9200 iterations the loss is 0.60866, the accuracy is 0.8104
# training! after 9200 iterations the loss is 0.192835, the accuracy is 0.929688
# ###################################
# validation! after 9300 iterations the loss is 0.606646, the accuracy is 0.815
# training! after 9300 iterations the loss is 0.136275, the accuracy is 0.953125
# ###################################
# validation! after 9400 iterations the loss is 0.633352, the accuracy is 0.8082
# training! after 9400 iterations the loss is 0.226627, the accuracy is 0.914062
# ###################################
# validation! after 9500 iterations the loss is 0.595943, the accuracy is 0.8208
# training! after 9500 iterations the loss is 0.20941, the accuracy is 0.929688
# ###################################
# validation! after 9600 iterations the loss is 0.598377, the accuracy is 0.818
# training! after 9600 iterations the loss is 0.274206, the accuracy is 0.914062
# ###################################
# validation! after 9700 iterations the loss is 0.614176, the accuracy is 0.8172
# training! after 9700 iterations the loss is 0.157722, the accuracy is 0.945312
# ###################################
# validation! after 9800 iterations the loss is 0.592155, the accuracy is 0.8128
# training! after 9800 iterations the loss is 0.21048, the accuracy is 0.945312
# ###################################
# validation! after 9900 iterations the loss is 0.614529, the accuracy is 0.8104
# training! after 9900 iterations the loss is 0.171952, the accuracy is 0.945312

# %%
# save_predictions('ans2-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans2-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
