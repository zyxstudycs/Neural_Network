# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
#         img_arr = img_arr / 255.0
        images.append(img_arr)
    X = np.column_stack(images)
#     print(images.shape)
#     print(X.shape)
    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'horse': 7, 'airplane': 0, 'automobile': 1, 'cat': 3, 'bird': 2, 'truck': 9, 'frog': 6, 'ship': 8, 'deer': 4, 'dog': 5}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [24106 26248  3012 ..., 26610 37087 38495]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
#         X_batch = np.reshape(X_batch, [batch_size, 32, 32, 3])
#         for i in range(batch_size):
#             get_distorted_image(X_batch[i])
        return X_batch, y_batch
    
def get_distorted_image(image):
#     X_batch = np.reshape(X_batch, [batch_size, 32, 32, 3])
#     for i in range(batch_size):
#         get_distorted_image(X_batch[i])
    d_img = tf.image.random_flip_left_right(image)
    d_img = tf.image.random_brightness(d_img, max_delta=63)
    d_img = tf.image.random_contrast(d_img, lower=0.2, upper=0.8)
    d_img = tf.image.per_image_standardization(d_img)
    
    return d_img
#     image = image.eval()
#     d_img = d_img.eval()
#     plt.imshow(image)
#     plt.figure()
#     plt.imshow(d_img)

# %%
logdir = 'tf_logs/summary_resNet4'
iteration = 15000
batch_size = 128
learning_rate = 0.001

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
regularizer = tf.contrib.layers.l2_regularizer(scale=0.1)
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])
#         input_layer = tf.reshape(X, [32, 32, 3])
        result = tf.map_fn(lambda img: get_distorted_image(img), input_layer)
#         distorted = get_distorted_image(X)

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=result, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1',
                                kernel_regularizer = regularizer)
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1,rate=0.2, training=training, name='dropout1')
#         pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=dropout1, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv2',
                                kernel_regularizer = regularizer)
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        combine2 = tf.add(batch_norm1, batch_norm2, name='combine2')
        dropout2 = tf.layers.dropout(combine2,rate=0.3, training=training, name='dropout2')
        
#         pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=dropout2, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv3',
                                kernel_regularizer = regularizer)
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        
        batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
        combine3 = tf.add(batch_norm3, combine2, name='combine3')
#         dropout3 = tf.layers.dropout(combine3, rate=0.4, training=training, name='dropout3')
        pool3 = tf.layers.max_pooling2d(inputs=combine3, pool_size=2, strides=2, padding='SAME', name='pool3')
        
    with tf.name_scope('conv4') as scope:
        conv4 = tf.layers.conv2d(inputs=pool3, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv4',
                                kernel_regularizer = regularizer)
        weight4= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv4')[0]
        
        batch_norm4 = tf.layers.batch_normalization(conv4, axis = 1, name='batch_norm4')
        combine4 = tf.add(pool3, batch_norm4, name='combine4')
        dropout4 = tf.layers.dropout(combine4,rate=0.3, training=training, name='dropout4')
#         pool4 = tf.layers.max_pooling2d(inputs=batch_norm4, pool_size=2, strides=2, padding='SAME', name='pool4')

    with tf.name_scope('conv5') as scope:
        conv5 = tf.layers.conv2d(inputs=dropout4, filters=128, kernel_size=3, strides=2, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv5',
                                kernel_regularizer = regularizer)
        weight5= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv5')[0]
        
        batch_norm5 = tf.layers.batch_normalization(conv5, axis = 1, name='batch_norm5')
        dropout5 = tf.layers.dropout(batch_norm5,rate=0.3, training=training, name='dropout5')
        
    with tf.name_scope('conv6') as scope:
        conv6 = tf.layers.conv2d(inputs=dropout5, filters=128, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv6',
                                kernel_regularizer = regularizer)
        weight6= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv6')[0]
        
        batch_norm6 = tf.layers.batch_normalization(conv6, axis = 1, name='batch_norm6')
        combine6 = tf.add(batch_norm5, batch_norm6, name='combine6')
#         dropout5 = tf.layers.dropout(batch_norm5,rate=0.3, training=training, name='dropout5')
        pool6 = tf.layers.max_pooling2d(inputs=combine6, pool_size=2, strides=2, padding='SAME', name='pool6')

    with tf.name_scope('conv7') as scope:
        conv7 = tf.layers.conv2d(inputs=pool6, filters=128, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv7',
                                kernel_regularizer = regularizer)
        weight7= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv7')[0]
        
        batch_norm7 = tf.layers.batch_normalization(conv7, axis = 1, name='batch_norm7')
        combine7 = tf.add(pool6, batch_norm7, name='combine7')
        dropout7 = tf.layers.dropout(combine7,rate=0.3, training=training, name='dropout7')
#         combine6 = tf.add(batch_norm5, batch_norm6, name='combine6')
#         dropout5 = tf.layers.dropout(batch_norm5,rate=0.3, training=training, name='dropout5')
#         pool6 = tf.layers.max_pooling2d(inputs=combine6, pool_size=2, strides=2, padding='SAME', name='pool6')
    
    with tf.name_scope('conv8') as scope:
        conv8 = tf.layers.conv2d(inputs=dropout7, filters=128, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv8',
                                kernel_regularizer = regularizer)
        weight8= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv8')[0]
        
        batch_norm8 = tf.layers.batch_normalization(conv8, axis = 1, name='batch_norm8')
        combine8 = tf.add(combine7, batch_norm8, name='combine8')
#         dropout8 = tf.layers.dropout(combine8,rate=0.4, training=training, name='dropout8')
    
    with tf.name_scope('fc') as scope:
        pool4_flat = tf.reshape(combine8, [-1, 4*4*128], name='pool4_flat')
        dropout_fc1 = tf.layers.dropout(pool4_flat, rate=0.4, training=training, name='dropout_fc1')
        
        dense1 = tf.layers.dense(dropout_fc1, units = 64, activation = tf.nn.relu, name='dense1',
                                kernel_regularizer = regularizer)
        batch_norm9 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm9')
        dropout_fc2 = tf.layers.dropout(batch_norm9, rate=0.3, training=training, name='dropout_fc2')
        
#         dense2 = tf.layers.dense(dropout_fc2, units = 128, activation = tf.nn.relu, name='dense2',
#                                 kernel_regularizer = regularizer)
#         batch_norm6 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm6')
#         dropout_fc3 = tf.layers.dropout(batch_norm6, rate=0.4, training=training, name='dropout_fc3')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout_fc2, units = 10, name='logits',kernel_regularizer = regularizer)
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    
        
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight4,'weight4')
        save_variable(weight5,'weight5')
        save_variable(weight6,'weight6')
        save_variable(weight7,'weight7')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(logits)
# Out:
# Tensor("logits/logits/BiasAdd:0", shape=(?, 10), dtype=float32, device=/device:GPU:0)

# %%
# config = tf.ConfigProto()
# config.allow_soft_placement = True
# with tf.Session(config=config) as sess:
    
#     X_batch, y_batch = get_batch(X_train, y_train, 1)
#     input_ ,distorted = sess.run([input_layer, distorted], feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
#     plt.imshow(input_)
#     plt.figure()
#     plt.imshow(distorted)

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.66599, the accuracy is 0.1034
# training! after 0 iterations the loss is 2.48816, the accuracy is 0.125
# ###################################
# validation! after 100 iterations the loss is 2.00286, the accuracy is 0.2492
# training! after 100 iterations the loss is 1.9399, the accuracy is 0.21875
# ###################################
# validation! after 200 iterations the loss is 1.75841, the accuracy is 0.3376
# training! after 200 iterations the loss is 1.72918, the accuracy is 0.367188
# ###################################
# validation! after 300 iterations the loss is 1.49964, the accuracy is 0.4498
# training! after 300 iterations the loss is 1.4329, the accuracy is 0.5
# ###################################
# validation! after 400 iterations the loss is 1.39848, the accuracy is 0.4818
# training! after 400 iterations the loss is 1.29761, the accuracy is 0.5625
# ###################################
# validation! after 500 iterations the loss is 1.2015, the accuracy is 0.5696
# training! after 500 iterations the loss is 1.12094, the accuracy is 0.640625
# ###################################
# validation! after 600 iterations the loss is 1.14748, the accuracy is 0.5826
# training! after 600 iterations the loss is 0.991145, the accuracy is 0.679688
# ###################################
# validation! after 700 iterations the loss is 1.10038, the accuracy is 0.6108
# training! after 700 iterations the loss is 1.04741, the accuracy is 0.570312
# ###################################
# validation! after 800 iterations the loss is 0.989804, the accuracy is 0.6458
# training! after 800 iterations the loss is 0.716237, the accuracy is 0.773438
# ###################################
# validation! after 900 iterations the loss is 0.943908, the accuracy is 0.6638
# training! after 900 iterations the loss is 0.870696, the accuracy is 0.640625
# ###################################
# validation! after 1000 iterations the loss is 0.880432, the accuracy is 0.6888
# training! after 1000 iterations the loss is 0.732764, the accuracy is 0.742188
# ###################################
# validation! after 1100 iterations the loss is 0.908723, the accuracy is 0.683
# training! after 1100 iterations the loss is 0.993032, the accuracy is 0.671875
# ###################################
# validation! after 1200 iterations the loss is 0.852801, the accuracy is 0.6948
# training! after 1200 iterations the loss is 0.594533, the accuracy is 0.773438
# ###################################
# validation! after 1300 iterations the loss is 0.81484, the accuracy is 0.7094
# training! after 1300 iterations the loss is 0.678812, the accuracy is 0.78125
# ###################################
# validation! after 1400 iterations the loss is 0.823834, the accuracy is 0.7084
# training! after 1400 iterations the loss is 0.693058, the accuracy is 0.726562
# ###################################
# validation! after 1500 iterations the loss is 0.809244, the accuracy is 0.7198
# training! after 1500 iterations the loss is 0.602206, the accuracy is 0.78125
# ###################################
# validation! after 1600 iterations the loss is 0.76189, the accuracy is 0.7314
# training! after 1600 iterations the loss is 0.710955, the accuracy is 0.71875
# ###################################
# validation! after 1700 iterations the loss is 0.76996, the accuracy is 0.7276
# training! after 1700 iterations the loss is 0.551624, the accuracy is 0.828125
# ###################################
# validation! after 1800 iterations the loss is 0.76982, the accuracy is 0.7234
# training! after 1800 iterations the loss is 0.594858, the accuracy is 0.820312
# ###################################
# validation! after 1900 iterations the loss is 0.738921, the accuracy is 0.7378
# training! after 1900 iterations the loss is 0.537252, the accuracy is 0.8125
# ###################################
# validation! after 2000 iterations the loss is 0.724434, the accuracy is 0.7406
# training! after 2000 iterations the loss is 0.822756, the accuracy is 0.679688
# ###################################
# validation! after 2100 iterations the loss is 0.727628, the accuracy is 0.7526
# training! after 2100 iterations the loss is 0.541969, the accuracy is 0.796875
# ###################################
# validation! after 2200 iterations the loss is 0.698724, the accuracy is 0.7516
# training! after 2200 iterations the loss is 0.616462, the accuracy is 0.820312
# ###################################
# validation! after 2300 iterations the loss is 0.709325, the accuracy is 0.7492
# training! after 2300 iterations the loss is 0.476347, the accuracy is 0.851562
# ###################################
# validation! after 2400 iterations the loss is 0.665058, the accuracy is 0.7668
# training! after 2400 iterations the loss is 0.656363, the accuracy is 0.78125
# ###################################
# validation! after 2500 iterations the loss is 0.669811, the accuracy is 0.7632
# training! after 2500 iterations the loss is 0.51064, the accuracy is 0.828125
# ###################################
# validation! after 2600 iterations the loss is 0.661899, the accuracy is 0.7668
# training! after 2600 iterations the loss is 0.552678, the accuracy is 0.796875
# ###################################
# validation! after 2700 iterations the loss is 0.662145, the accuracy is 0.775
# training! after 2700 iterations the loss is 0.509081, the accuracy is 0.78125
# ###################################
# validation! after 2800 iterations the loss is 0.669216, the accuracy is 0.7718
# training! after 2800 iterations the loss is 0.439146, the accuracy is 0.84375
# ###################################
# validation! after 2900 iterations the loss is 0.655438, the accuracy is 0.7762
# training! after 2900 iterations the loss is 0.503678, the accuracy is 0.789062
# ###################################
# validation! after 3000 iterations the loss is 0.633853, the accuracy is 0.7816
# training! after 3000 iterations the loss is 0.494471, the accuracy is 0.859375
# ###################################
# validation! after 3100 iterations the loss is 0.650856, the accuracy is 0.7738
# training! after 3100 iterations the loss is 0.463088, the accuracy is 0.828125
# ###################################
# validation! after 3200 iterations the loss is 0.626228, the accuracy is 0.786
# training! after 3200 iterations the loss is 0.478289, the accuracy is 0.867188
# ###################################
# validation! after 3300 iterations the loss is 0.618447, the accuracy is 0.79
# training! after 3300 iterations the loss is 0.485433, the accuracy is 0.789062
# ###################################
# validation! after 3400 iterations the loss is 0.656484, the accuracy is 0.7764
# training! after 3400 iterations the loss is 0.420582, the accuracy is 0.835938
# ###################################
# validation! after 3500 iterations the loss is 0.628648, the accuracy is 0.7734
# training! after 3500 iterations the loss is 0.491772, the accuracy is 0.8125
# ###################################
# validation! after 3600 iterations the loss is 0.610446, the accuracy is 0.7876
# training! after 3600 iterations the loss is 0.596633, the accuracy is 0.789062
# ###################################
# validation! after 3700 iterations the loss is 0.617334, the accuracy is 0.7832
# training! after 3700 iterations the loss is 0.433874, the accuracy is 0.804688
# ###################################
# validation! after 3800 iterations the loss is 0.600049, the accuracy is 0.7944
# training! after 3800 iterations the loss is 0.486572, the accuracy is 0.8125
# ###################################
# validation! after 3900 iterations the loss is 0.627011, the accuracy is 0.789
# training! after 3900 iterations the loss is 0.3283, the accuracy is 0.898438
# ###################################
# validation! after 4000 iterations the loss is 0.586167, the accuracy is 0.8
# training! after 4000 iterations the loss is 0.302496, the accuracy is 0.890625
# ###################################
# validation! after 4100 iterations the loss is 0.629862, the accuracy is 0.7806
# training! after 4100 iterations the loss is 0.345464, the accuracy is 0.882812
# ###################################
# validation! after 4200 iterations the loss is 0.591712, the accuracy is 0.798
# training! after 4200 iterations the loss is 0.427057, the accuracy is 0.84375
# ###################################
# validation! after 4300 iterations the loss is 0.583562, the accuracy is 0.8022
# training! after 4300 iterations the loss is 0.746018, the accuracy is 0.742188
# ###################################
# validation! after 4400 iterations the loss is 0.582473, the accuracy is 0.804
# training! after 4400 iterations the loss is 0.310475, the accuracy is 0.882812
# ###################################
# validation! after 4500 iterations the loss is 0.587391, the accuracy is 0.7974
# training! after 4500 iterations the loss is 0.365527, the accuracy is 0.859375
# ###################################
# validation! after 4600 iterations the loss is 0.560672, the accuracy is 0.8096
# training! after 4600 iterations the loss is 0.389979, the accuracy is 0.875
# ###################################
# validation! after 4700 iterations the loss is 0.572136, the accuracy is 0.8036
# training! after 4700 iterations the loss is 0.552212, the accuracy is 0.8125
# ###################################
# validation! after 4800 iterations the loss is 0.586882, the accuracy is 0.8074
# training! after 4800 iterations the loss is 0.401775, the accuracy is 0.882812
# ###################################
# validation! after 4900 iterations the loss is 0.584553, the accuracy is 0.8096
# training! after 4900 iterations the loss is 0.258639, the accuracy is 0.914062
# ###################################
# validation! after 5000 iterations the loss is 0.579038, the accuracy is 0.8012
# training! after 5000 iterations the loss is 0.310596, the accuracy is 0.898438
# ###################################
# validation! after 5100 iterations the loss is 0.575917, the accuracy is 0.8074
# training! after 5100 iterations the loss is 0.444351, the accuracy is 0.820312
# ###################################
# validation! after 5200 iterations the loss is 0.564402, the accuracy is 0.8086
# training! after 5200 iterations the loss is 0.313106, the accuracy is 0.890625
# ###################################
# validation! after 5300 iterations the loss is 0.563841, the accuracy is 0.8108
# training! after 5300 iterations the loss is 0.238581, the accuracy is 0.929688
# ###################################
# validation! after 5400 iterations the loss is 0.564024, the accuracy is 0.8036
# training! after 5400 iterations the loss is 0.287886, the accuracy is 0.882812
# ###################################
# validation! after 5500 iterations the loss is 0.556089, the accuracy is 0.8166
# training! after 5500 iterations the loss is 0.330198, the accuracy is 0.875
# ###################################
# validation! after 5600 iterations the loss is 0.567691, the accuracy is 0.8136
# training! after 5600 iterations the loss is 0.232367, the accuracy is 0.914062
# ###################################
# validation! after 5700 iterations the loss is 0.556941, the accuracy is 0.8148
# training! after 5700 iterations the loss is 0.479222, the accuracy is 0.789062
# ###################################
# validation! after 5800 iterations the loss is 0.565684, the accuracy is 0.8174
# training! after 5800 iterations the loss is 0.46961, the accuracy is 0.828125
# ###################################
# validation! after 5900 iterations the loss is 0.538525, the accuracy is 0.8244
# training! after 5900 iterations the loss is 0.321612, the accuracy is 0.875
# ###################################
# validation! after 6000 iterations the loss is 0.538485, the accuracy is 0.8234
# training! after 6000 iterations the loss is 0.255752, the accuracy is 0.890625
# ###################################
# validation! after 6100 iterations the loss is 0.529381, the accuracy is 0.8208
# training! after 6100 iterations the loss is 0.214259, the accuracy is 0.929688
# ###################################
# validation! after 6200 iterations the loss is 0.570839, the accuracy is 0.8146
# training! after 6200 iterations the loss is 0.241868, the accuracy is 0.890625
# ###################################
# validation! after 6300 iterations the loss is 0.536783, the accuracy is 0.8218
# training! after 6300 iterations the loss is 0.178302, the accuracy is 0.945312
# ###################################
# validation! after 6400 iterations the loss is 0.549291, the accuracy is 0.8178
# training! after 6400 iterations the loss is 0.330887, the accuracy is 0.875
# ###################################
# validation! after 6500 iterations the loss is 0.568307, the accuracy is 0.8178
# training! after 6500 iterations the loss is 0.263619, the accuracy is 0.898438
# ###################################
# validation! after 6600 iterations the loss is 0.568958, the accuracy is 0.8178
# training! after 6600 iterations the loss is 0.310298, the accuracy is 0.882812
# ###################################
# validation! after 6700 iterations the loss is 0.562701, the accuracy is 0.811
# training! after 6700 iterations the loss is 0.251613, the accuracy is 0.898438
# ###################################
# validation! after 6800 iterations the loss is 0.544121, the accuracy is 0.8172
# training! after 6800 iterations the loss is 0.248908, the accuracy is 0.882812
# ###################################
# validation! after 6900 iterations the loss is 0.520719, the accuracy is 0.8284
# training! after 6900 iterations the loss is 0.270357, the accuracy is 0.890625
# ###################################
# validation! after 7000 iterations the loss is 0.545997, the accuracy is 0.8228
# training! after 7000 iterations the loss is 0.143616, the accuracy is 0.945312
# ###################################
# validation! after 7100 iterations the loss is 0.515405, the accuracy is 0.8354
# training! after 7100 iterations the loss is 0.345048, the accuracy is 0.882812
# ###################################
# validation! after 7200 iterations the loss is 0.541494, the accuracy is 0.8206
# training! after 7200 iterations the loss is 0.268615, the accuracy is 0.914062
# ###################################
# validation! after 7300 iterations the loss is 0.538547, the accuracy is 0.8246
# training! after 7300 iterations the loss is 0.156713, the accuracy is 0.953125
# ###################################
# validation! after 7400 iterations the loss is 0.524918, the accuracy is 0.83
# training! after 7400 iterations the loss is 0.331388, the accuracy is 0.890625
# ###################################
# validation! after 7500 iterations the loss is 0.537237, the accuracy is 0.8242
# training! after 7500 iterations the loss is 0.194584, the accuracy is 0.929688
# ###################################
# validation! after 7600 iterations the loss is 0.55168, the accuracy is 0.8194
# training! after 7600 iterations the loss is 0.316951, the accuracy is 0.890625
# ###################################
# validation! after 7700 iterations the loss is 0.540968, the accuracy is 0.8238
# training! after 7700 iterations the loss is 0.232926, the accuracy is 0.914062
# ###################################
# validation! after 7800 iterations the loss is 0.52842, the accuracy is 0.8328
# training! after 7800 iterations the loss is 0.271168, the accuracy is 0.882812
# ###################################
# validation! after 7900 iterations the loss is 0.501956, the accuracy is 0.8346
# training! after 7900 iterations the loss is 0.158478, the accuracy is 0.9375
# ###################################
# validation! after 8000 iterations the loss is 0.534114, the accuracy is 0.8278
# training! after 8000 iterations the loss is 0.155426, the accuracy is 0.953125
# ###################################
# validation! after 8100 iterations the loss is 0.521987, the accuracy is 0.8314
# training! after 8100 iterations the loss is 0.290152, the accuracy is 0.898438
# ###################################
# validation! after 8200 iterations the loss is 0.51795, the accuracy is 0.8266
# training! after 8200 iterations the loss is 0.212639, the accuracy is 0.898438
# ###################################
# validation! after 8300 iterations the loss is 0.533623, the accuracy is 0.8258
# training! after 8300 iterations the loss is 0.259173, the accuracy is 0.90625
# ###################################
# validation! after 8400 iterations the loss is 0.504006, the accuracy is 0.8342
# training! after 8400 iterations the loss is 0.189301, the accuracy is 0.929688
# ###################################
# validation! after 8500 iterations the loss is 0.547746, the accuracy is 0.8236
# training! after 8500 iterations the loss is 0.224772, the accuracy is 0.914062
# ###################################
# validation! after 8600 iterations the loss is 0.528443, the accuracy is 0.825
# training! after 8600 iterations the loss is 0.226609, the accuracy is 0.929688
# ###################################
# validation! after 8700 iterations the loss is 0.512786, the accuracy is 0.8328
# training! after 8700 iterations the loss is 0.218503, the accuracy is 0.929688
# ###################################
# validation! after 8800 iterations the loss is 0.504701, the accuracy is 0.8338
# training! after 8800 iterations the loss is 0.187428, the accuracy is 0.9375
# ###################################
# validation! after 8900 iterations the loss is 0.516479, the accuracy is 0.83
# training! after 8900 iterations the loss is 0.196096, the accuracy is 0.929688
# ###################################
# validation! after 9000 iterations the loss is 0.5094, the accuracy is 0.8348
# training! after 9000 iterations the loss is 0.225042, the accuracy is 0.914062
# ###################################
# validation! after 9100 iterations the loss is 0.512154, the accuracy is 0.8308
# training! after 9100 iterations the loss is 0.179821, the accuracy is 0.921875
# ###################################
# validation! after 9200 iterations the loss is 0.508393, the accuracy is 0.833
# training! after 9200 iterations the loss is 0.226713, the accuracy is 0.921875
# ###################################
# validation! after 9300 iterations the loss is 0.505433, the accuracy is 0.8302
# training! after 9300 iterations the loss is 0.153661, the accuracy is 0.953125
# ###################################
# validation! after 9400 iterations the loss is 0.495305, the accuracy is 0.835
# training! after 9400 iterations the loss is 0.244531, the accuracy is 0.921875
# ###################################
# validation! after 9500 iterations the loss is 0.495766, the accuracy is 0.8322
# training! after 9500 iterations the loss is 0.168955, the accuracy is 0.929688
# ###################################
# validation! after 9600 iterations the loss is 0.496109, the accuracy is 0.8394
# training! after 9600 iterations the loss is 0.19651, the accuracy is 0.9375
# ###################################
# validation! after 9700 iterations the loss is 0.484218, the accuracy is 0.8414
# training! after 9700 iterations the loss is 0.294845, the accuracy is 0.90625
# ###################################
# validation! after 9800 iterations the loss is 0.503431, the accuracy is 0.8402
# training! after 9800 iterations the loss is 0.12789, the accuracy is 0.945312
# ###################################
# validation! after 9900 iterations the loss is 0.494833, the accuracy is 0.8452
# training! after 9900 iterations the loss is 0.227521, the accuracy is 0.921875
# ###################################
# validation! after 10000 iterations the loss is 0.494041, the accuracy is 0.8454
# training! after 10000 iterations the loss is 0.133977, the accuracy is 0.960938
# ###################################
# validation! after 10100 iterations the loss is 0.511536, the accuracy is 0.8406
# training! after 10100 iterations the loss is 0.200457, the accuracy is 0.921875
# ###################################
# validation! after 10200 iterations the loss is 0.502394, the accuracy is 0.8366
# training! after 10200 iterations the loss is 0.0902123, the accuracy is 0.984375
# ###################################
# validation! after 10300 iterations the loss is 0.497598, the accuracy is 0.8402
# training! after 10300 iterations the loss is 0.180679, the accuracy is 0.945312
# ###################################
# validation! after 10400 iterations the loss is 0.497134, the accuracy is 0.8458
# training! after 10400 iterations the loss is 0.163731, the accuracy is 0.929688
# ###################################
# validation! after 10500 iterations the loss is 0.475809, the accuracy is 0.8482
# training! after 10500 iterations the loss is 0.190617, the accuracy is 0.914062
# ###################################
# validation! after 10600 iterations the loss is 0.492517, the accuracy is 0.8432
# training! after 10600 iterations the loss is 0.205858, the accuracy is 0.90625
# ###################################
# validation! after 10700 iterations the loss is 0.48063, the accuracy is 0.845
# training! after 10700 iterations the loss is 0.136876, the accuracy is 0.953125
# ###################################
# validation! after 10800 iterations the loss is 0.49783, the accuracy is 0.8402
# training! after 10800 iterations the loss is 0.136821, the accuracy is 0.953125
# ###################################
# validation! after 10900 iterations the loss is 0.472372, the accuracy is 0.8456
# training! after 10900 iterations the loss is 0.195053, the accuracy is 0.945312
# ###################################
# validation! after 11000 iterations the loss is 0.500819, the accuracy is 0.844
# training! after 11000 iterations the loss is 0.171599, the accuracy is 0.9375
# ###################################
# validation! after 11100 iterations the loss is 0.511911, the accuracy is 0.8388
# training! after 11100 iterations the loss is 0.203087, the accuracy is 0.945312
# ###################################
# validation! after 11200 iterations the loss is 0.485247, the accuracy is 0.8444
# training! after 11200 iterations the loss is 0.203952, the accuracy is 0.929688
# ###################################
# validation! after 11300 iterations the loss is 0.489754, the accuracy is 0.847
# training! after 11300 iterations the loss is 0.188446, the accuracy is 0.945312
# ###################################
# validation! after 11400 iterations the loss is 0.493972, the accuracy is 0.8444
# training! after 11400 iterations the loss is 0.13575, the accuracy is 0.960938
# ###################################
# validation! after 11500 iterations the loss is 0.502232, the accuracy is 0.838
# training! after 11500 iterations the loss is 0.183198, the accuracy is 0.9375
# ###################################
# validation! after 11600 iterations the loss is 0.480325, the accuracy is 0.845
# training! after 11600 iterations the loss is 0.137481, the accuracy is 0.960938
# ###################################
# validation! after 11700 iterations the loss is 0.479004, the accuracy is 0.8484
# training! after 11700 iterations the loss is 0.206845, the accuracy is 0.953125
# ###################################
# validation! after 11800 iterations the loss is 0.476098, the accuracy is 0.8452
# training! after 11800 iterations the loss is 0.236599, the accuracy is 0.9375
# ###################################
# validation! after 11900 iterations the loss is 0.494884, the accuracy is 0.8422
# training! after 11900 iterations the loss is 0.182049, the accuracy is 0.9375
# ###################################
# validation! after 12000 iterations the loss is 0.47366, the accuracy is 0.8484
# training! after 12000 iterations the loss is 0.176675, the accuracy is 0.9375
# ###################################
# validation! after 12100 iterations the loss is 0.488032, the accuracy is 0.8458
# training! after 12100 iterations the loss is 0.170019, the accuracy is 0.9375
# ###################################
# validation! after 12200 iterations the loss is 0.485146, the accuracy is 0.8416
# training! after 12200 iterations the loss is 0.127794, the accuracy is 0.960938
# ###################################
# validation! after 12300 iterations the loss is 0.49506, the accuracy is 0.8434
# training! after 12300 iterations the loss is 0.0649833, the accuracy is 0.992188
# ###################################
# validation! after 12400 iterations the loss is 0.50311, the accuracy is 0.8458
# training! after 12400 iterations the loss is 0.0959647, the accuracy is 0.96875
# ###################################
# validation! after 12500 iterations the loss is 0.494338, the accuracy is 0.8432
# training! after 12500 iterations the loss is 0.157704, the accuracy is 0.953125
# ###################################
# validation! after 12600 iterations the loss is 0.482845, the accuracy is 0.8486
# training! after 12600 iterations the loss is 0.141722, the accuracy is 0.960938
# ###################################
# validation! after 12700 iterations the loss is 0.483579, the accuracy is 0.8488
# training! after 12700 iterations the loss is 0.123612, the accuracy is 0.960938
# ###################################
# validation! after 12800 iterations the loss is 0.486642, the accuracy is 0.8512
# training! after 12800 iterations the loss is 0.13693, the accuracy is 0.945312
# ###################################
# validation! after 12900 iterations the loss is 0.483197, the accuracy is 0.856
# training! after 12900 iterations the loss is 0.207867, the accuracy is 0.945312
# ###################################
# validation! after 13000 iterations the loss is 0.470467, the accuracy is 0.855
# training! after 13000 iterations the loss is 0.125443, the accuracy is 0.945312
# ###################################
# validation! after 13100 iterations the loss is 0.480689, the accuracy is 0.85
# training! after 13100 iterations the loss is 0.0905275, the accuracy is 0.96875
# ###################################
# validation! after 13200 iterations the loss is 0.458323, the accuracy is 0.8542
# training! after 13200 iterations the loss is 0.156229, the accuracy is 0.953125
# ###################################
# validation! after 13300 iterations the loss is 0.489982, the accuracy is 0.847
# training! after 13300 iterations the loss is 0.12175, the accuracy is 0.96875
# ###################################
# validation! after 13400 iterations the loss is 0.472855, the accuracy is 0.8608
# training! after 13400 iterations the loss is 0.141243, the accuracy is 0.9375
# ###################################
# validation! after 13500 iterations the loss is 0.487695, the accuracy is 0.8542
# training! after 13500 iterations the loss is 0.14078, the accuracy is 0.953125
# ###################################
# validation! after 13600 iterations the loss is 0.489552, the accuracy is 0.8498
# training! after 13600 iterations the loss is 0.117202, the accuracy is 0.960938
# ###################################
# validation! after 13700 iterations the loss is 0.481681, the accuracy is 0.8518
# training! after 13700 iterations the loss is 0.15872, the accuracy is 0.960938
# ###################################
# validation! after 13800 iterations the loss is 0.463017, the accuracy is 0.8566
# training! after 13800 iterations the loss is 0.211934, the accuracy is 0.9375
# ###################################
# validation! after 13900 iterations the loss is 0.476218, the accuracy is 0.857
# training! after 13900 iterations the loss is 0.135636, the accuracy is 0.960938
# ###################################
# validation! after 14000 iterations the loss is 0.501298, the accuracy is 0.8492
# training! after 14000 iterations the loss is 0.0876169, the accuracy is 0.96875
# ###################################
# validation! after 14100 iterations the loss is 0.490549, the accuracy is 0.8504
# training! after 14100 iterations the loss is 0.137346, the accuracy is 0.960938
# ###################################
# validation! after 14200 iterations the loss is 0.488032, the accuracy is 0.8456
# training! after 14200 iterations the loss is 0.123734, the accuracy is 0.945312
# ###################################
# validation! after 14300 iterations the loss is 0.478534, the accuracy is 0.8548
# training! after 14300 iterations the loss is 0.162215, the accuracy is 0.945312
# ###################################
# validation! after 14400 iterations the loss is 0.47124, the accuracy is 0.8534
# training! after 14400 iterations the loss is 0.287543, the accuracy is 0.890625
# ###################################
# validation! after 14500 iterations the loss is 0.465885, the accuracy is 0.8602
# training! after 14500 iterations the loss is 0.134916, the accuracy is 0.945312
# ###################################
# validation! after 14600 iterations the loss is 0.481358, the accuracy is 0.8534
# training! after 14600 iterations the loss is 0.180354, the accuracy is 0.9375
# ###################################
# validation! after 14700 iterations the loss is 0.491611, the accuracy is 0.8556
# training! after 14700 iterations the loss is 0.171842, the accuracy is 0.929688
# ###################################
# validation! after 14800 iterations the loss is 0.517956, the accuracy is 0.8458
# training! after 14800 iterations the loss is 0.154027, the accuracy is 0.953125
# ###################################
# validation! after 14900 iterations the loss is 0.485573, the accuracy is 0.854
# training! after 14900 iterations the loss is 0.0849127, the accuracy is 0.960938

# %%
save_predictions('ans2-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans2-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
# Out:
# (10, 10000)
# array([[ -0.07254168,  10.40071011,   6.96945763, ...,  -8.60781956,
#          -0.30845132,  -5.30182266],
#        [ -4.25405407,  12.66198921,  -6.03877735, ...,  -6.85159302,
#          10.0753479 ,  -6.51480007],
#        [ -0.51743031,  -1.4073509 ,   0.83241349, ...,   6.32799435,
#          -0.39114469,  -0.57954508],
#        ...,
#        [ -1.3303473 ,  -5.6273613 ,   0.79260683, ...,   5.71583748,
#          -2.96765161,  23.36368942],
#        [ -2.02939081,  23.23748589,  -2.87284589, ...,  -5.24417973,
#          -2.71986508, -10.87773418],
#        [ -3.29899573,   9.86066532,  -3.26939797, ...,  -7.88169718,
#           3.98659897,  -4.21644115]], dtype=float32)
