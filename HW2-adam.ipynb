# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'frog': 6, 'horse': 7, 'airplane': 0, 'ship': 8, 'deer': 4, 'truck': 9, 'bird': 2, 'cat': 3, 'automobile': 1, 'dog': 5}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [40498 34861 31369 ..., 38254 44557  6277]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary_adam_dropout'
iteration = 6000
batch_size = 128
learning_rate = 0.001

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1')
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1, rate=0.3, training=training, name='dropout1')
#         pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=dropout1, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv2')
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=pool2, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv3')
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
        dropout3 = tf.layers.dropout(batch_norm3, rate=0.3, training=training, name='dropout3')
#         pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2, padding='SAME', name='pool3')
        
    with tf.name_scope('conv4') as scope:
        conv4 = tf.layers.conv2d(inputs=dropout3, filters=256, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv4')
        weight4= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv4')[0]
        batch_norm4 = tf.layers.batch_normalization(conv4, axis = 1, name='batch_norm4')
        pool4 = tf.layers.max_pooling2d(inputs=batch_norm4, pool_size=2, strides=2, padding='SAME', name='pool4')

    with tf.name_scope('fc') as scope:
        pool4_flat = tf.reshape(pool4, [-1, 8*8*256], name='pool4_flat')
        dropout_fc1 = tf.layers.dropout(pool4_flat, rate=0.3, training=training, name='dropout_fc1')
        
        dense1 = tf.layers.dense(dropout_fc1, units = 8*128, activation = tf.nn.relu, name='dense1')
        batch_norm5 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm5')
        dropout_fc2 = tf.layers.dropout(batch_norm5, rate=0.3, training=training, name='dropout_fc2')
        
        dense2 = tf.layers.dense(dropout_fc2, units = 128, activation = tf.nn.relu, name='dense2')
        batch_norm6 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm6')
        dropout_fc3 = tf.layers.dropout(batch_norm6, rate=0.3, training=training, name='dropout_fc3')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout_fc3, units = 10, name='logits')
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    
        
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight4,'weight4')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(weight4)
# Out:
# <tf.Variable 'conv4/kernel:0' shape=(3, 3, 128, 256) dtype=float32_ref>

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.32537, the accuracy is 0.0974
# training! after 0 iterations the loss is 2.29289, the accuracy is 0.140625
# ###################################
# validation! after 100 iterations the loss is 2.0261, the accuracy is 0.2728
# training! after 100 iterations the loss is 1.96692, the accuracy is 0.257812
# ###################################
# validation! after 200 iterations the loss is 1.55218, the accuracy is 0.4456
# training! after 200 iterations the loss is 1.51786, the accuracy is 0.453125
# ###################################
# validation! after 300 iterations the loss is 1.3136, the accuracy is 0.5278
# training! after 300 iterations the loss is 1.10737, the accuracy is 0.601562
# ###################################
# validation! after 400 iterations the loss is 1.18833, the accuracy is 0.5798
# training! after 400 iterations the loss is 0.994106, the accuracy is 0.710938
# ###################################
# validation! after 500 iterations the loss is 1.079, the accuracy is 0.6184
# training! after 500 iterations the loss is 1.19179, the accuracy is 0.59375
# ###################################
# validation! after 600 iterations the loss is 1.04755, the accuracy is 0.6296
# training! after 600 iterations the loss is 1.24226, the accuracy is 0.539062
# ###################################
# validation! after 700 iterations the loss is 0.950111, the accuracy is 0.6626
# training! after 700 iterations the loss is 0.681912, the accuracy is 0.789062
# ###################################
# validation! after 800 iterations the loss is 0.879691, the accuracy is 0.6888
# training! after 800 iterations the loss is 0.460107, the accuracy is 0.8125
# ###################################
# validation! after 900 iterations the loss is 0.986018, the accuracy is 0.679
# training! after 900 iterations the loss is 0.774418, the accuracy is 0.726562
# ###################################
# validation! after 1000 iterations the loss is 0.855027, the accuracy is 0.7038
# training! after 1000 iterations the loss is 0.66449, the accuracy is 0.773438
# ###################################
# validation! after 1100 iterations the loss is 0.930046, the accuracy is 0.6906
# training! after 1100 iterations the loss is 0.724554, the accuracy is 0.734375
# ###################################
# validation! after 1200 iterations the loss is 0.852265, the accuracy is 0.7096
# training! after 1200 iterations the loss is 0.479819, the accuracy is 0.820312
# ###################################
# validation! after 1300 iterations the loss is 0.804953, the accuracy is 0.7264
# training! after 1300 iterations the loss is 0.417448, the accuracy is 0.828125
# ###################################
# validation! after 1400 iterations the loss is 0.826721, the accuracy is 0.7292
# training! after 1400 iterations the loss is 0.22523, the accuracy is 0.921875
# ###################################
# validation! after 1500 iterations the loss is 0.790331, the accuracy is 0.7384
# training! after 1500 iterations the loss is 0.377926, the accuracy is 0.875
# ###################################
# validation! after 1600 iterations the loss is 0.814062, the accuracy is 0.7496
# training! after 1600 iterations the loss is 0.423287, the accuracy is 0.890625
# ###################################
# validation! after 1700 iterations the loss is 0.76068, the accuracy is 0.7524
# training! after 1700 iterations the loss is 0.464479, the accuracy is 0.84375
# ###################################
# validation! after 1800 iterations the loss is 0.759456, the accuracy is 0.7528
# training! after 1800 iterations the loss is 0.0952558, the accuracy is 0.976562
# ###################################
# validation! after 1900 iterations the loss is 0.75552, the accuracy is 0.763
# training! after 1900 iterations the loss is 0.367769, the accuracy is 0.835938
# ###################################
# validation! after 2000 iterations the loss is 0.744571, the accuracy is 0.7648
# training! after 2000 iterations the loss is 0.156666, the accuracy is 0.945312
# ###################################
# validation! after 2100 iterations the loss is 0.732001, the accuracy is 0.7636
# training! after 2100 iterations the loss is 0.370507, the accuracy is 0.851562
# ###################################
# validation! after 2200 iterations the loss is 0.769649, the accuracy is 0.7676
# training! after 2200 iterations the loss is 0.316865, the accuracy is 0.875
# ###################################
# validation! after 2300 iterations the loss is 0.798902, the accuracy is 0.7636
# training! after 2300 iterations the loss is 0.173812, the accuracy is 0.960938
# ###################################
# validation! after 2400 iterations the loss is 0.776594, the accuracy is 0.7718
# training! after 2400 iterations the loss is 0.0851493, the accuracy is 0.976562
# ###################################
# validation! after 2500 iterations the loss is 0.75012, the accuracy is 0.7692
# training! after 2500 iterations the loss is 0.0842252, the accuracy is 0.984375
# ###################################
# validation! after 2600 iterations the loss is 0.755186, the accuracy is 0.7786
# training! after 2600 iterations the loss is 0.0923158, the accuracy is 0.96875
# ###################################
# validation! after 2700 iterations the loss is 0.756762, the accuracy is 0.7696
# training! after 2700 iterations the loss is 0.0369029, the accuracy is 0.992188
# ###################################
# validation! after 2800 iterations the loss is 0.765605, the accuracy is 0.7802
# training! after 2800 iterations the loss is 0.0588578, the accuracy is 0.976562
# ###################################
# validation! after 2900 iterations the loss is 0.770752, the accuracy is 0.7756
# training! after 2900 iterations the loss is 0.126608, the accuracy is 0.96875
# ###################################
# validation! after 3000 iterations the loss is 0.767712, the accuracy is 0.7844
# training! after 3000 iterations the loss is 0.0735032, the accuracy is 0.96875
# ###################################
# validation! after 3100 iterations the loss is 0.809657, the accuracy is 0.7792
# training! after 3100 iterations the loss is 0.0730481, the accuracy is 0.976562
# ###################################
# validation! after 3200 iterations the loss is 0.837694, the accuracy is 0.7682
# training! after 3200 iterations the loss is 0.068275, the accuracy is 0.976562
# ###################################
# validation! after 3300 iterations the loss is 0.809162, the accuracy is 0.778
# training! after 3300 iterations the loss is 0.0478859, the accuracy is 0.992188
# ###################################
# validation! after 3400 iterations the loss is 0.798077, the accuracy is 0.7886
# training! after 3400 iterations the loss is 0.0835969, the accuracy is 0.96875
# ###################################
# validation! after 3500 iterations the loss is 0.836078, the accuracy is 0.781
# training! after 3500 iterations the loss is 0.0492254, the accuracy is 0.976562
# ###################################
# validation! after 3600 iterations the loss is 0.870263, the accuracy is 0.772
# training! after 3600 iterations the loss is 0.0360253, the accuracy is 0.984375
# ###################################
# validation! after 3700 iterations the loss is 0.874335, the accuracy is 0.7804
# training! after 3700 iterations the loss is 0.0307114, the accuracy is 0.992188
# ###################################
# validation! after 3800 iterations the loss is 0.970071, the accuracy is 0.7618
# training! after 3800 iterations the loss is 0.0749979, the accuracy is 0.96875
# ###################################
# validation! after 3900 iterations the loss is 0.817542, the accuracy is 0.7808
# training! after 3900 iterations the loss is 0.0218667, the accuracy is 1.0
# ###################################
# validation! after 4000 iterations the loss is 0.856806, the accuracy is 0.7746
# training! after 4000 iterations the loss is 0.0186477, the accuracy is 0.992188
# ###################################
# validation! after 4100 iterations the loss is 0.844688, the accuracy is 0.7762
# training! after 4100 iterations the loss is 0.0100995, the accuracy is 1.0
# ###################################
# validation! after 4200 iterations the loss is 0.847053, the accuracy is 0.783
# training! after 4200 iterations the loss is 0.0765908, the accuracy is 0.96875
# ###################################
# validation! after 4300 iterations the loss is 0.905318, the accuracy is 0.776
# training! after 4300 iterations the loss is 0.024178, the accuracy is 0.984375
# ###################################
# validation! after 4400 iterations the loss is 0.838885, the accuracy is 0.779
# training! after 4400 iterations the loss is 0.0189751, the accuracy is 0.992188
# ###################################
# validation! after 4500 iterations the loss is 0.889173, the accuracy is 0.7804
# training! after 4500 iterations the loss is 0.0946647, the accuracy is 0.960938
# ###################################
# validation! after 4600 iterations the loss is 0.829847, the accuracy is 0.7854
# training! after 4600 iterations the loss is 0.0184879, the accuracy is 1.0
# ###################################
# validation! after 4700 iterations the loss is 0.838423, the accuracy is 0.778
# training! after 4700 iterations the loss is 0.0355721, the accuracy is 0.992188
# ###################################
# validation! after 4800 iterations the loss is 0.855624, the accuracy is 0.785
# training! after 4800 iterations the loss is 0.00531689, the accuracy is 1.0
# ###################################
# validation! after 4900 iterations the loss is 0.927685, the accuracy is 0.781
# training! after 4900 iterations the loss is 0.00691074, the accuracy is 1.0
# ###################################
# validation! after 5000 iterations the loss is 0.906838, the accuracy is 0.7798
# training! after 5000 iterations the loss is 0.0420628, the accuracy is 0.984375
# ###################################
# validation! after 5100 iterations the loss is 0.884422, the accuracy is 0.7872
# training! after 5100 iterations the loss is 0.011436, the accuracy is 1.0
# ###################################
# validation! after 5200 iterations the loss is 0.930929, the accuracy is 0.783
# training! after 5200 iterations the loss is 0.00878528, the accuracy is 1.0
# ###################################
# validation! after 5300 iterations the loss is 0.86445, the accuracy is 0.7832
# training! after 5300 iterations the loss is 0.00750152, the accuracy is 1.0
# ###################################
# validation! after 5400 iterations the loss is 0.906057, the accuracy is 0.782
# training! after 5400 iterations the loss is 0.0110849, the accuracy is 1.0
# ###################################
# validation! after 5500 iterations the loss is 0.920521, the accuracy is 0.7838
# training! after 5500 iterations the loss is 0.0216142, the accuracy is 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-65502cacbabb> in <module>()
# ----> 1 y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
#
# <ipython-input-12-2081c85362cd> in train(X_train, y_train, X_validation, y_validation, iteration, X_test)
#       8         for step in range(iteration):
#       9             X_batch, y_batch = get_batch(X_train, y_train, batch_size)
# ---> 10             sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
#      11
#      12             if step % 100 == 0:
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# save_predictions('ans2-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans2-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
