# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'horse': 7, 'truck': 9, 'airplane': 0, 'frog': 6, 'dog': 5, 'ship': 8, 'deer': 4, 'automobile': 1, 'bird': 2, 'cat': 3}
# Loaded 10000/50000
# Loaded 20000/50000

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [ 6102 20915 21286 ..., 11124 31987 12959]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary6'
iteration = 20000
batch_size = 128
learning_rate = 0.005

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1')
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=pool1, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv2')
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=pool2, filters=256, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv3')
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
        pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2, padding='SAME', name='pool3')

    with tf.name_scope('fc') as scope:
        pool3_flat = tf.reshape(pool3, [-1, 4*4*256], name='pool3_flat')
#         dropout1 = tf.layers.dropout(pool3_flat, rate=dropout_rate, training=training, name='dropout1')
        dense1 = tf.layers.dense(pool3_flat, units = 8*128, activation = tf.nn.relu, name='dense1')
        batch_norm4 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm4')
#         dropout2 = tf.layers.dropout(dense1, rate=dropout_rate, training=training, name='dropout2')
        dense2 = tf.layers.dense(batch_norm4, units = 128, activation = tf.nn.relu, name='dense2')
#         dropout3 = tf.layers.dropout(dense2, rate=dropout_rate, training=training, name='dropout3')
        batch_norm5 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm5')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(batch_norm5, units = 10, name='logits')
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    
        
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(weight_logits)
# Out:
# <tf.Variable 'logits/kernel:0' shape=(128, 10) dtype=float32_ref>

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.30684, the accuracy is 0.0762
# training! after 0 iterations the loss is 2.29689, the accuracy is 0.078125
# ###################################
# validation! after 100 iterations the loss is 2.28018, the accuracy is 0.1968
# training! after 100 iterations the loss is 2.28238, the accuracy is 0.15625
# ###################################
# validation! after 200 iterations the loss is 2.23453, the accuracy is 0.2164
# training! after 200 iterations the loss is 2.21737, the accuracy is 0.257812
# ###################################
# validation! after 300 iterations the loss is 2.12366, the accuracy is 0.2468
# training! after 300 iterations the loss is 2.07845, the accuracy is 0.28125
# ###################################
# validation! after 400 iterations the loss is 2.16044, the accuracy is 0.217
# training! after 400 iterations the loss is 2.04954, the accuracy is 0.203125
# ###################################
# validation! after 500 iterations the loss is 1.99577, the accuracy is 0.2734
# training! after 500 iterations the loss is 1.87654, the accuracy is 0.375
# ###################################
# validation! after 600 iterations the loss is 1.97023, the accuracy is 0.2806
# training! after 600 iterations the loss is 1.78492, the accuracy is 0.40625
# ###################################
# validation! after 700 iterations the loss is 1.95408, the accuracy is 0.3088
# training! after 700 iterations the loss is 1.82356, the accuracy is 0.328125
# ###################################
# validation! after 800 iterations the loss is 1.94309, the accuracy is 0.313
# training! after 800 iterations the loss is 1.75916, the accuracy is 0.367188
# ###################################
# validation! after 900 iterations the loss is 1.83265, the accuracy is 0.3444
# training! after 900 iterations the loss is 1.7915, the accuracy is 0.382812
# ###################################
# validation! after 1000 iterations the loss is 1.8494, the accuracy is 0.3424
# training! after 1000 iterations the loss is 1.81245, the accuracy is 0.367188
# ###################################
# validation! after 1100 iterations the loss is 1.81884, the accuracy is 0.3538
# training! after 1100 iterations the loss is 1.7737, the accuracy is 0.390625
# ###################################
# validation! after 1200 iterations the loss is 1.74817, the accuracy is 0.3836
# training! after 1200 iterations the loss is 1.65027, the accuracy is 0.34375
# ###################################
# validation! after 1300 iterations the loss is 1.70876, the accuracy is 0.3966
# training! after 1300 iterations the loss is 1.57755, the accuracy is 0.445312
# ###################################
# validation! after 1400 iterations the loss is 1.69032, the accuracy is 0.4092
# training! after 1400 iterations the loss is 1.51058, the accuracy is 0.5
# ###################################
# validation! after 1500 iterations the loss is 1.66672, the accuracy is 0.409
# training! after 1500 iterations the loss is 1.64825, the accuracy is 0.4375
# ###################################
# validation! after 1600 iterations the loss is 1.64249, the accuracy is 0.4202
# training! after 1600 iterations the loss is 1.66034, the accuracy is 0.34375
# ###################################
# validation! after 1700 iterations the loss is 1.60715, the accuracy is 0.4372
# training! after 1700 iterations the loss is 1.47313, the accuracy is 0.46875
# ###################################
# validation! after 1800 iterations the loss is 1.55792, the accuracy is 0.447
# training! after 1800 iterations the loss is 1.46025, the accuracy is 0.492188
# ###################################
# validation! after 1900 iterations the loss is 1.62826, the accuracy is 0.422
# training! after 1900 iterations the loss is 1.3619, the accuracy is 0.53125
# ###################################
# validation! after 2000 iterations the loss is 1.66033, the accuracy is 0.426
# training! after 2000 iterations the loss is 1.51008, the accuracy is 0.476562
# ###################################
# validation! after 2100 iterations the loss is 1.57926, the accuracy is 0.4412
# training! after 2100 iterations the loss is 1.44823, the accuracy is 0.523438
# ###################################
# validation! after 2200 iterations the loss is 1.46496, the accuracy is 0.4812
# training! after 2200 iterations the loss is 1.35749, the accuracy is 0.539062
# ###################################
# validation! after 2300 iterations the loss is 1.51735, the accuracy is 0.4672
# training! after 2300 iterations the loss is 1.3764, the accuracy is 0.484375
# ###################################
# validation! after 2400 iterations the loss is 1.44607, the accuracy is 0.4832
# training! after 2400 iterations the loss is 1.37728, the accuracy is 0.515625
# ###################################
# validation! after 2500 iterations the loss is 1.47242, the accuracy is 0.4808
# training! after 2500 iterations the loss is 1.21894, the accuracy is 0.601562
# ###################################
# validation! after 2600 iterations the loss is 1.41019, the accuracy is 0.4996
# training! after 2600 iterations the loss is 1.25339, the accuracy is 0.546875
# ###################################
# validation! after 2700 iterations the loss is 1.40113, the accuracy is 0.5004
# training! after 2700 iterations the loss is 1.3182, the accuracy is 0.539062
# ###################################
# validation! after 2800 iterations the loss is 1.399, the accuracy is 0.505
# training! after 2800 iterations the loss is 1.5263, the accuracy is 0.46875
# ###################################
# validation! after 2900 iterations the loss is 1.39609, the accuracy is 0.5094
# training! after 2900 iterations the loss is 1.25464, the accuracy is 0.578125
# ###################################
# validation! after 3000 iterations the loss is 1.37315, the accuracy is 0.5116
# training! after 3000 iterations the loss is 1.2361, the accuracy is 0.609375
# ###################################
# validation! after 3100 iterations the loss is 1.35226, the accuracy is 0.523
# training! after 3100 iterations the loss is 1.19488, the accuracy is 0.59375
# ###################################
# validation! after 3200 iterations the loss is 1.4806, the accuracy is 0.4816
# training! after 3200 iterations the loss is 1.26689, the accuracy is 0.601562
# ###################################
# validation! after 3300 iterations the loss is 1.36645, the accuracy is 0.518
# training! after 3300 iterations the loss is 1.08944, the accuracy is 0.664062
# ###################################
# validation! after 3400 iterations the loss is 1.38596, the accuracy is 0.5156
# training! after 3400 iterations the loss is 1.17054, the accuracy is 0.570312
# ###################################
# validation! after 3500 iterations the loss is 1.36442, the accuracy is 0.5214
# training! after 3500 iterations the loss is 1.10706, the accuracy is 0.617188
# ###################################
# validation! after 3600 iterations the loss is 1.3286, the accuracy is 0.5378
# training! after 3600 iterations the loss is 1.09991, the accuracy is 0.609375
# ###################################
# validation! after 3700 iterations the loss is 1.2831, the accuracy is 0.5442
# training! after 3700 iterations the loss is 1.1284, the accuracy is 0.578125
# ###################################
# validation! after 3800 iterations the loss is 1.27769, the accuracy is 0.5462
# training! after 3800 iterations the loss is 1.32005, the accuracy is 0.539062
# ###################################
# validation! after 3900 iterations the loss is 1.26497, the accuracy is 0.5476
# training! after 3900 iterations the loss is 1.00108, the accuracy is 0.664062
# ###################################
# validation! after 4000 iterations the loss is 1.25964, the accuracy is 0.5596
# training! after 4000 iterations the loss is 1.05074, the accuracy is 0.6875
# ###################################
# validation! after 4100 iterations the loss is 1.27244, the accuracy is 0.555
# training! after 4100 iterations the loss is 1.09077, the accuracy is 0.585938
# ###################################
# validation! after 4200 iterations the loss is 1.25434, the accuracy is 0.55
# training! after 4200 iterations the loss is 0.965789, the accuracy is 0.671875
# ###################################
# validation! after 4300 iterations the loss is 1.22975, the accuracy is 0.5668
# training! after 4300 iterations the loss is 1.03141, the accuracy is 0.679688
# ###################################
# validation! after 4400 iterations the loss is 1.26111, the accuracy is 0.5522
# training! after 4400 iterations the loss is 0.939943, the accuracy is 0.671875
# ###################################
# validation! after 4500 iterations the loss is 1.21949, the accuracy is 0.5716
# training! after 4500 iterations the loss is 0.922041, the accuracy is 0.710938
# ###################################
# validation! after 4600 iterations the loss is 1.20822, the accuracy is 0.5784
# training! after 4600 iterations the loss is 1.01115, the accuracy is 0.6875
# ###################################
# validation! after 4700 iterations the loss is 1.25346, the accuracy is 0.5648
# training! after 4700 iterations the loss is 0.989169, the accuracy is 0.671875
# ###################################
# validation! after 4800 iterations the loss is 1.17531, the accuracy is 0.5874
# training! after 4800 iterations the loss is 0.950742, the accuracy is 0.6875
# ###################################
# validation! after 4900 iterations the loss is 1.25694, the accuracy is 0.5592
# training! after 4900 iterations the loss is 1.06719, the accuracy is 0.648438
# ###################################
# validation! after 5000 iterations the loss is 1.18253, the accuracy is 0.598
# training! after 5000 iterations the loss is 1.00227, the accuracy is 0.617188
# ###################################
# validation! after 5100 iterations the loss is 1.23757, the accuracy is 0.5676
# training! after 5100 iterations the loss is 0.95385, the accuracy is 0.6875
# ###################################
# validation! after 5200 iterations the loss is 1.16651, the accuracy is 0.5982
# training! after 5200 iterations the loss is 0.837056, the accuracy is 0.710938
# ###################################
# validation! after 5300 iterations the loss is 1.14551, the accuracy is 0.595
# training! after 5300 iterations the loss is 0.992373, the accuracy is 0.632812
# ###################################
# validation! after 5400 iterations the loss is 1.23147, the accuracy is 0.5728
# training! after 5400 iterations the loss is 0.969172, the accuracy is 0.65625
# ###################################
# validation! after 5500 iterations the loss is 1.14825, the accuracy is 0.6014
# training! after 5500 iterations the loss is 0.773277, the accuracy is 0.734375
# ###################################
# validation! after 5600 iterations the loss is 1.13885, the accuracy is 0.6034
# training! after 5600 iterations the loss is 0.806888, the accuracy is 0.71875
# ###################################
# validation! after 5700 iterations the loss is 1.11659, the accuracy is 0.6088
# training! after 5700 iterations the loss is 0.736119, the accuracy is 0.75
# ###################################
# validation! after 5800 iterations the loss is 1.11748, the accuracy is 0.6044
# training! after 5800 iterations the loss is 0.825753, the accuracy is 0.734375
# ###################################
# validation! after 5900 iterations the loss is 1.12987, the accuracy is 0.6058
# training! after 5900 iterations the loss is 0.719491, the accuracy is 0.742188
# ###################################
# validation! after 6000 iterations the loss is 1.12042, the accuracy is 0.6082
# training! after 6000 iterations the loss is 0.747865, the accuracy is 0.726562
# ###################################
# validation! after 6100 iterations the loss is 1.10298, the accuracy is 0.6154
# training! after 6100 iterations the loss is 0.776499, the accuracy is 0.734375
# ###################################
# validation! after 6200 iterations the loss is 1.13082, the accuracy is 0.6048
# training! after 6200 iterations the loss is 0.838685, the accuracy is 0.75
# ###################################
# validation! after 6300 iterations the loss is 1.10781, the accuracy is 0.6198
# training! after 6300 iterations the loss is 0.834562, the accuracy is 0.6875
# ###################################
# validation! after 6400 iterations the loss is 1.18761, the accuracy is 0.5918
# training! after 6400 iterations the loss is 0.757321, the accuracy is 0.765625
# ###################################
# validation! after 6500 iterations the loss is 1.0824, the accuracy is 0.6246
# training! after 6500 iterations the loss is 0.68227, the accuracy is 0.789062
# ###################################
# validation! after 6600 iterations the loss is 1.05893, the accuracy is 0.6246
# training! after 6600 iterations the loss is 0.825757, the accuracy is 0.695312
# ###################################
# validation! after 6700 iterations the loss is 1.0528, the accuracy is 0.6298
# training! after 6700 iterations the loss is 0.7397, the accuracy is 0.75
# ###################################
# validation! after 6800 iterations the loss is 1.04557, the accuracy is 0.6314
# training! after 6800 iterations the loss is 0.724765, the accuracy is 0.796875
# ###################################
# validation! after 6900 iterations the loss is 1.09175, the accuracy is 0.6238
# training! after 6900 iterations the loss is 0.713184, the accuracy is 0.773438
# ###################################
# validation! after 7000 iterations the loss is 1.13566, the accuracy is 0.6118
# training! after 7000 iterations the loss is 0.772005, the accuracy is 0.71875
# ###################################
# validation! after 7100 iterations the loss is 1.09038, the accuracy is 0.621
# training! after 7100 iterations the loss is 0.705554, the accuracy is 0.757812
# ###################################
# validation! after 7200 iterations the loss is 1.03077, the accuracy is 0.6378
# training! after 7200 iterations the loss is 0.589546, the accuracy is 0.867188
# ###################################
# validation! after 7300 iterations the loss is 1.07951, the accuracy is 0.6274
# training! after 7300 iterations the loss is 0.789101, the accuracy is 0.710938
# ###################################
# validation! after 7400 iterations the loss is 1.01132, the accuracy is 0.6492
# training! after 7400 iterations the loss is 0.618359, the accuracy is 0.789062
# ###################################
# validation! after 7500 iterations the loss is 1.04131, the accuracy is 0.6386
# training! after 7500 iterations the loss is 0.543067, the accuracy is 0.820312
# ###################################
# validation! after 7600 iterations the loss is 1.03315, the accuracy is 0.6418
# training! after 7600 iterations the loss is 0.522157, the accuracy is 0.84375
# ###################################
# validation! after 7700 iterations the loss is 1.09603, the accuracy is 0.6284
# training! after 7700 iterations the loss is 0.509703, the accuracy is 0.859375
# ###################################
# validation! after 7800 iterations the loss is 1.07137, the accuracy is 0.6272
# training! after 7800 iterations the loss is 0.861178, the accuracy is 0.679688
# ###################################
# validation! after 7900 iterations the loss is 1.07415, the accuracy is 0.6318
# training! after 7900 iterations the loss is 0.592074, the accuracy is 0.796875
# ###################################
# validation! after 8000 iterations the loss is 1.09627, the accuracy is 0.6264
# training! after 8000 iterations the loss is 0.478272, the accuracy is 0.828125
# ###################################
# validation! after 8100 iterations the loss is 1.00281, the accuracy is 0.654
# training! after 8100 iterations the loss is 0.553172, the accuracy is 0.859375
# ###################################
# validation! after 8200 iterations the loss is 1.05524, the accuracy is 0.6396
# training! after 8200 iterations the loss is 0.57585, the accuracy is 0.835938
# ###################################
# validation! after 8300 iterations the loss is 1.03176, the accuracy is 0.6378
# training! after 8300 iterations the loss is 0.537791, the accuracy is 0.835938
# ###################################
# validation! after 8400 iterations the loss is 1.01238, the accuracy is 0.6538
# training! after 8400 iterations the loss is 0.431646, the accuracy is 0.875
# ###################################
# validation! after 8500 iterations the loss is 1.01452, the accuracy is 0.6554
# training! after 8500 iterations the loss is 0.523474, the accuracy is 0.859375
# ###################################
# validation! after 8600 iterations the loss is 1.11947, the accuracy is 0.6314
# training! after 8600 iterations the loss is 0.517666, the accuracy is 0.84375
# ###################################
# validation! after 8700 iterations the loss is 1.03806, the accuracy is 0.6472
# training! after 8700 iterations the loss is 0.632591, the accuracy is 0.804688
# ###################################
# validation! after 8800 iterations the loss is 1.00172, the accuracy is 0.6596
# training! after 8800 iterations the loss is 0.546416, the accuracy is 0.804688
# ###################################
# validation! after 8900 iterations the loss is 1.00986, the accuracy is 0.6578
# training! after 8900 iterations the loss is 0.499027, the accuracy is 0.875
# ###################################
# validation! after 9000 iterations the loss is 1.03449, the accuracy is 0.6502
# training! after 9000 iterations the loss is 0.519859, the accuracy is 0.820312
# ###################################
# validation! after 9100 iterations the loss is 0.983479, the accuracy is 0.6698
# training! after 9100 iterations the loss is 0.36432, the accuracy is 0.914062
# ###################################
# validation! after 9200 iterations the loss is 1.02557, the accuracy is 0.6538
# training! after 9200 iterations the loss is 0.328669, the accuracy is 0.914062
# ###################################
# validation! after 9300 iterations the loss is 1.05193, the accuracy is 0.6472
# training! after 9300 iterations the loss is 0.388076, the accuracy is 0.90625
# ###################################
# validation! after 9400 iterations the loss is 1.0248, the accuracy is 0.6582
# training! after 9400 iterations the loss is 0.365851, the accuracy is 0.898438
# ###################################
# validation! after 9500 iterations the loss is 1.06839, the accuracy is 0.652
# training! after 9500 iterations the loss is 0.369383, the accuracy is 0.90625
# ###################################
# validation! after 9600 iterations the loss is 1.09666, the accuracy is 0.6448
# training! after 9600 iterations the loss is 0.321388, the accuracy is 0.90625
# ###################################
# validation! after 9700 iterations the loss is 1.09743, the accuracy is 0.6388
# training! after 9700 iterations the loss is 0.443417, the accuracy is 0.867188
# ###################################
# validation! after 9800 iterations the loss is 1.03924, the accuracy is 0.6638
# training! after 9800 iterations the loss is 0.290664, the accuracy is 0.921875
# ###################################
# validation! after 9900 iterations the loss is 1.0222, the accuracy is 0.6578
# training! after 9900 iterations the loss is 0.3407, the accuracy is 0.90625
# ###################################
# validation! after 10000 iterations the loss is 0.990754, the accuracy is 0.6788
# training! after 10000 iterations the loss is 0.247073, the accuracy is 0.945312
# ###################################
# validation! after 10100 iterations the loss is 1.11344, the accuracy is 0.6488
# training! after 10100 iterations the loss is 0.348776, the accuracy is 0.882812
# ###################################
# validation! after 10200 iterations the loss is 1.04596, the accuracy is 0.659
# training! after 10200 iterations the loss is 0.469149, the accuracy is 0.84375
# ###################################
# validation! after 10300 iterations the loss is 1.07296, the accuracy is 0.6588
# training! after 10300 iterations the loss is 0.407735, the accuracy is 0.898438
# ###################################
# validation! after 10400 iterations the loss is 1.00553, the accuracy is 0.6756
# training! after 10400 iterations the loss is 0.245383, the accuracy is 0.960938
# ###################################
# validation! after 10500 iterations the loss is 0.993425, the accuracy is 0.6804
# training! after 10500 iterations the loss is 0.201661, the accuracy is 0.976562
# ###################################
# validation! after 10600 iterations the loss is 1.01342, the accuracy is 0.6712
# training! after 10600 iterations the loss is 0.275725, the accuracy is 0.914062
# ###################################
# validation! after 10700 iterations the loss is 1.01508, the accuracy is 0.6734
# training! after 10700 iterations the loss is 0.167708, the accuracy is 0.976562
# ###################################
# validation! after 10800 iterations the loss is 1.04459, the accuracy is 0.676
# training! after 10800 iterations the loss is 0.292903, the accuracy is 0.921875
# ###################################
# validation! after 10900 iterations the loss is 0.998107, the accuracy is 0.6804
# training! after 10900 iterations the loss is 0.222287, the accuracy is 0.960938
# ###################################
# validation! after 11000 iterations the loss is 1.04614, the accuracy is 0.66
# training! after 11000 iterations the loss is 0.334566, the accuracy is 0.921875
# ###################################
# validation! after 11100 iterations the loss is 1.1432, the accuracy is 0.6564
# training! after 11100 iterations the loss is 0.323554, the accuracy is 0.898438
# ###################################
# validation! after 11200 iterations the loss is 1.03704, the accuracy is 0.6726
# training! after 11200 iterations the loss is 0.220179, the accuracy is 0.976562
# ###################################
# validation! after 11300 iterations the loss is 1.05429, the accuracy is 0.668
# training! after 11300 iterations the loss is 0.310412, the accuracy is 0.929688
# ###################################
# validation! after 11400 iterations the loss is 1.07436, the accuracy is 0.6674
# training! after 11400 iterations the loss is 0.266743, the accuracy is 0.90625
# ###################################
# validation! after 11500 iterations the loss is 1.08872, the accuracy is 0.6652
# training! after 11500 iterations the loss is 0.168325, the accuracy is 0.976562
# ###################################
# validation! after 11600 iterations the loss is 1.07371, the accuracy is 0.6752
# training! after 11600 iterations the loss is 0.184225, the accuracy is 0.953125
# ###################################
# validation! after 11700 iterations the loss is 1.12985, the accuracy is 0.663
# training! after 11700 iterations the loss is 0.221807, the accuracy is 0.953125
# ###################################
# validation! after 11800 iterations the loss is 1.05424, the accuracy is 0.6706
# training! after 11800 iterations the loss is 0.183564, the accuracy is 0.96875
# ###################################
# validation! after 11900 iterations the loss is 1.06756, the accuracy is 0.678
# training! after 11900 iterations the loss is 0.168738, the accuracy is 0.960938
# ###################################
# validation! after 12000 iterations the loss is 1.10113, the accuracy is 0.6688
# training! after 12000 iterations the loss is 0.307128, the accuracy is 0.882812
# ###################################
# validation! after 12100 iterations the loss is 1.05033, the accuracy is 0.68
# training! after 12100 iterations the loss is 0.0938068, the accuracy is 0.992188
# ###################################
# validation! after 12200 iterations the loss is 1.07493, the accuracy is 0.6794
# training! after 12200 iterations the loss is 0.17025, the accuracy is 0.960938
# ###################################
# validation! after 12300 iterations the loss is 1.07471, the accuracy is 0.679
# training! after 12300 iterations the loss is 0.149788, the accuracy is 0.976562
# ###################################
# validation! after 12400 iterations the loss is 1.05858, the accuracy is 0.6856
# training! after 12400 iterations the loss is 0.142559, the accuracy is 0.984375
# ###################################
# validation! after 12500 iterations the loss is 1.12462, the accuracy is 0.6756
# training! after 12500 iterations the loss is 0.195857, the accuracy is 0.929688
# ###################################
# validation! after 12600 iterations the loss is 1.0998, the accuracy is 0.687
# training! after 12600 iterations the loss is 0.0880452, the accuracy is 1.0
# ###################################
# validation! after 12700 iterations the loss is 1.09899, the accuracy is 0.6828
# training! after 12700 iterations the loss is 0.0734191, the accuracy is 0.992188
# ###################################
# validation! after 12800 iterations the loss is 1.16938, the accuracy is 0.674
# training! after 12800 iterations the loss is 0.102348, the accuracy is 1.0
# ###################################
# validation! after 12900 iterations the loss is 1.09875, the accuracy is 0.6874
# training! after 12900 iterations the loss is 0.0805969, the accuracy is 1.0
# ###################################
# validation! after 13000 iterations the loss is 1.15253, the accuracy is 0.682
# training! after 13000 iterations the loss is 0.116575, the accuracy is 0.96875
# ###################################
# validation! after 13100 iterations the loss is 1.10554, the accuracy is 0.685
# training! after 13100 iterations the loss is 0.072131, the accuracy is 0.992188
# ###################################
# validation! after 13200 iterations the loss is 1.16654, the accuracy is 0.6784
# training! after 13200 iterations the loss is 0.0911763, the accuracy is 0.984375
# ###################################
# validation! after 13300 iterations the loss is 1.23144, the accuracy is 0.669
# training! after 13300 iterations the loss is 0.146861, the accuracy is 0.960938
# ###################################
# validation! after 13400 iterations the loss is 1.14007, the accuracy is 0.6862
# training! after 13400 iterations the loss is 0.0412394, the accuracy is 1.0
# ###################################
# validation! after 13500 iterations the loss is 1.16915, the accuracy is 0.6852
# training! after 13500 iterations the loss is 0.0394843, the accuracy is 1.0
# ###################################
# validation! after 13600 iterations the loss is 1.17334, the accuracy is 0.6874
# training! after 13600 iterations the loss is 0.0687365, the accuracy is 0.992188
# ###################################
# validation! after 13700 iterations the loss is 2.08606, the accuracy is 0.5768
# training! after 13700 iterations the loss is 0.683241, the accuracy is 0.851562
# ###################################
# validation! after 13800 iterations the loss is 1.33646, the accuracy is 0.659
# training! after 13800 iterations the loss is 0.156089, the accuracy is 0.96875
# ###################################
# validation! after 13900 iterations the loss is 1.31334, the accuracy is 0.6714
# training! after 13900 iterations the loss is 0.170563, the accuracy is 0.921875
# ###################################
# validation! after 14000 iterations the loss is 1.18919, the accuracy is 0.689
# training! after 14000 iterations the loss is 0.0397023, the accuracy is 1.0
# ###################################
# validation! after 14100 iterations the loss is 1.26231, the accuracy is 0.6794
# training! after 14100 iterations the loss is 0.0741334, the accuracy is 0.992188
# ###################################
# validation! after 14200 iterations the loss is 1.26854, the accuracy is 0.68
# training! after 14200 iterations the loss is 0.0369808, the accuracy is 1.0
# ###################################
# validation! after 14300 iterations the loss is 1.25773, the accuracy is 0.6826
# training! after 14300 iterations the loss is 0.0277865, the accuracy is 1.0
# ###################################
# validation! after 14400 iterations the loss is 1.25417, the accuracy is 0.6884
# training! after 14400 iterations the loss is 0.042102, the accuracy is 1.0
# ###################################
# validation! after 14500 iterations the loss is 1.34733, the accuracy is 0.6768
# training! after 14500 iterations the loss is 0.113329, the accuracy is 0.96875
# ###################################
# validation! after 14600 iterations the loss is 1.34832, the accuracy is 0.6694
# training! after 14600 iterations the loss is 0.100013, the accuracy is 0.960938
# ###################################
# validation! after 14700 iterations the loss is 1.28544, the accuracy is 0.6892
# training! after 14700 iterations the loss is 0.0156732, the accuracy is 1.0
# ###################################
# validation! after 14800 iterations the loss is 1.32885, the accuracy is 0.6862
# training! after 14800 iterations the loss is 0.0198352, the accuracy is 1.0
# ###################################
# validation! after 14900 iterations the loss is 1.33214, the accuracy is 0.6806
# training! after 14900 iterations the loss is 0.0373536, the accuracy is 1.0
# ###################################
# validation! after 15000 iterations the loss is 1.29263, the accuracy is 0.69
# training! after 15000 iterations the loss is 0.0242609, the accuracy is 1.0
# ###################################
# validation! after 15100 iterations the loss is 1.34112, the accuracy is 0.6876
# training! after 15100 iterations the loss is 0.0186008, the accuracy is 1.0
# ###################################
# validation! after 15200 iterations the loss is 4.73942, the accuracy is 0.4132
# training! after 15200 iterations the loss is 2.88458, the accuracy is 0.609375
# ###################################
# validation! after 15300 iterations the loss is 1.27892, the accuracy is 0.6894
# training! after 15300 iterations the loss is 0.0254674, the accuracy is 1.0
# ###################################
# validation! after 15400 iterations the loss is 1.35031, the accuracy is 0.688
# training! after 15400 iterations the loss is 0.0375912, the accuracy is 1.0
# ###################################
# validation! after 15500 iterations the loss is 1.26408, the accuracy is 0.6946
# training! after 15500 iterations the loss is 0.0317157, the accuracy is 1.0
# ###################################
# validation! after 15600 iterations the loss is 1.35035, the accuracy is 0.6926
# training! after 15600 iterations the loss is 0.0138173, the accuracy is 1.0
# ###################################
# validation! after 15700 iterations the loss is 1.47702, the accuracy is 0.676
# training! after 15700 iterations the loss is 0.0671568, the accuracy is 0.976562
# ###################################
# validation! after 15800 iterations the loss is 1.53667, the accuracy is 0.668
# training! after 15800 iterations the loss is 0.0686385, the accuracy is 0.984375
# ###################################
# validation! after 15900 iterations the loss is 1.3976, the accuracy is 0.694
# training! after 15900 iterations the loss is 0.0172841, the accuracy is 1.0
# ###################################
# validation! after 16000 iterations the loss is 1.43199, the accuracy is 0.6936
# training! after 16000 iterations the loss is 0.0126928, the accuracy is 1.0
# ###################################
# validation! after 16100 iterations the loss is 1.43683, the accuracy is 0.6834
# training! after 16100 iterations the loss is 0.0122659, the accuracy is 1.0
# ###################################
# validation! after 16200 iterations the loss is 1.45125, the accuracy is 0.6932
# training! after 16200 iterations the loss is 0.0129157, the accuracy is 1.0
# ###################################
# validation! after 16300 iterations the loss is 1.49432, the accuracy is 0.6874
# training! after 16300 iterations the loss is 0.0119692, the accuracy is 1.0
# ###################################
# validation! after 16400 iterations the loss is 1.48411, the accuracy is 0.6954
# training! after 16400 iterations the loss is 0.00697806, the accuracy is 1.0
# ###################################
# validation! after 16500 iterations the loss is 1.32692, the accuracy is 0.683
# training! after 16500 iterations the loss is 0.017491, the accuracy is 1.0
# ###################################
# validation! after 16600 iterations the loss is 1.41908, the accuracy is 0.6936
# training! after 16600 iterations the loss is 0.0140848, the accuracy is 1.0
# ###################################
# validation! after 16700 iterations the loss is 1.48304, the accuracy is 0.6918
# training! after 16700 iterations the loss is 0.017482, the accuracy is 1.0
# ###################################
# validation! after 16800 iterations the loss is 1.5063, the accuracy is 0.6928
# training! after 16800 iterations the loss is 0.0126768, the accuracy is 1.0
# ###################################
# validation! after 16900 iterations the loss is 1.38514, the accuracy is 0.6926
# training! after 16900 iterations the loss is 0.0126328, the accuracy is 1.0
# ###################################
# validation! after 17000 iterations the loss is 1.4697, the accuracy is 0.694
# training! after 17000 iterations the loss is 0.00878072, the accuracy is 1.0
# ###################################
# validation! after 17100 iterations the loss is 1.59202, the accuracy is 0.6826
# training! after 17100 iterations the loss is 0.0450923, the accuracy is 0.992188
# ###################################
# validation! after 17200 iterations the loss is 1.53338, the accuracy is 0.6912
# training! after 17200 iterations the loss is 0.00729356, the accuracy is 1.0
# ###################################
# validation! after 17300 iterations the loss is 1.54509, the accuracy is 0.694
# training! after 17300 iterations the loss is 0.00613044, the accuracy is 1.0
# ###################################
# validation! after 17400 iterations the loss is 1.55941, the accuracy is 0.6918
# training! after 17400 iterations the loss is 0.00697767, the accuracy is 1.0
# ###################################
# validation! after 17500 iterations the loss is 1.58735, the accuracy is 0.6928
# training! after 17500 iterations the loss is 0.00707163, the accuracy is 1.0
# ###################################
# validation! after 17600 iterations the loss is 1.61383, the accuracy is 0.6948
# training! after 17600 iterations the loss is 0.00735778, the accuracy is 1.0
# ###################################
# validation! after 17700 iterations the loss is 1.3608, the accuracy is 0.6848
# training! after 17700 iterations the loss is 0.0309413, the accuracy is 1.0
# ###################################
# validation! after 17800 iterations the loss is 1.45006, the accuracy is 0.6928
# training! after 17800 iterations the loss is 0.0190647, the accuracy is 1.0

# %%
# save_predictions('ans1-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
