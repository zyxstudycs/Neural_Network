# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'horse': 7, 'frog': 6, 'dog': 5, 'deer': 4, 'cat': 3, 'ship': 8, 'truck': 9, 'automobile': 1, 'bird': 2, 'airplane': 0}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [27720 43361 36702 ..., 44699 37719 31338]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary_resNet1'
iteration = 6000
batch_size = 128
learning_rate = 0.001

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
regularizer = tf.contrib.layers.l2_regularizer(scale=0.1)
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1',
                                kernel_regularizer = regularizer)
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1,rate=0.3, training=training, name='dropout1')
#         pool1 = tf.layers.max_pooling2d(inputs=batch_norm1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=dropout1, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv2',
                                kernel_regularizer = regularizer)
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        
        combine2 = tf.add(dropout1, conv2, name='combine2')
        batch_norm2 = tf.layers.batch_normalization(combine2, axis = 1, name='batch_norm2')
        pool2 = tf.layers.max_pooling2d(inputs=batch_norm2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=pool2, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv3',
                                kernel_regularizer = regularizer)
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        
        combine3 = tf.add(pool2, conv3, name='combine3')
        batch_norm3 = tf.layers.batch_normalization(combine3, axis = 1, name='batch_norm3')
        dropout3 = tf.layers.dropout(batch_norm3, rate=0.4, training=training, name='dropout3')
#         pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2, padding='SAME', name='pool3')
        
    with tf.name_scope('conv4') as scope:
        conv4 = tf.layers.conv2d(inputs=dropout3, filters=128, kernel_size=3, strides=2, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv4',
                                kernel_regularizer = regularizer)
        weight4= tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv4')[0]
        batch_norm4 = tf.layers.batch_normalization(conv4, axis = 1, name='batch_norm4')
        pool4 = tf.layers.max_pooling2d(inputs=batch_norm4, pool_size=2, strides=2, padding='SAME', name='pool4')

    with tf.name_scope('fc') as scope:
        pool4_flat = tf.reshape(pool4, [-1, 4*4*128], name='pool4_flat')
        dropout_fc1 = tf.layers.dropout(pool4_flat, rate=0.4, training=training, name='dropout_fc1')
        
        dense1 = tf.layers.dense(dropout_fc1, units = 8*128, activation = tf.nn.relu, name='dense1',
                                kernel_regularizer = regularizer)
        batch_norm5 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm5')
        dropout_fc2 = tf.layers.dropout(batch_norm5, rate=0.4, training=training, name='dropout_fc2')
        
        dense2 = tf.layers.dense(dropout_fc2, units = 128, activation = tf.nn.relu, name='dense2',
                                kernel_regularizer = regularizer)
        batch_norm6 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm6')
        dropout_fc3 = tf.layers.dropout(batch_norm6, rate=0.5, training=training, name='dropout_fc3')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout_fc3, units = 10, name='logits',kernel_regularizer = regularizer)
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.AdamOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    
        
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight4,'weight4')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(weight4)
# Out:
# <tf.Variable 'conv4/kernel:0' shape=(3, 3, 64, 128) dtype=float32_ref>

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.31684, the accuracy is 0.105
# training! after 0 iterations the loss is 2.26612, the accuracy is 0.171875
# ###################################
# validation! after 100 iterations the loss is 1.81497, the accuracy is 0.3416
# training! after 100 iterations the loss is 1.73117, the accuracy is 0.34375
# ###################################
# validation! after 200 iterations the loss is 1.55267, the accuracy is 0.4504
# training! after 200 iterations the loss is 1.36466, the accuracy is 0.523438
# ###################################
# validation! after 300 iterations the loss is 1.28518, the accuracy is 0.5442
# training! after 300 iterations the loss is 1.1813, the accuracy is 0.570312
# ###################################
# validation! after 400 iterations the loss is 1.19155, the accuracy is 0.579
# training! after 400 iterations the loss is 1.14287, the accuracy is 0.632812
# ###################################
# validation! after 500 iterations the loss is 1.19591, the accuracy is 0.5704
# training! after 500 iterations the loss is 1.16391, the accuracy is 0.554688
# ###################################
# validation! after 600 iterations the loss is 1.01661, the accuracy is 0.6376
# training! after 600 iterations the loss is 0.822496, the accuracy is 0.710938
# ###################################
# validation! after 700 iterations the loss is 0.944807, the accuracy is 0.6632
# training! after 700 iterations the loss is 1.0235, the accuracy is 0.625
# ###################################
# validation! after 800 iterations the loss is 0.972773, the accuracy is 0.6596
# training! after 800 iterations the loss is 0.909659, the accuracy is 0.648438
# ###################################
# validation! after 900 iterations the loss is 0.862293, the accuracy is 0.6946
# training! after 900 iterations the loss is 0.679248, the accuracy is 0.773438
# ###################################
# validation! after 1000 iterations the loss is 0.848678, the accuracy is 0.7006
# training! after 1000 iterations the loss is 0.680914, the accuracy is 0.757812
# ###################################
# validation! after 1100 iterations the loss is 0.833652, the accuracy is 0.7146
# training! after 1100 iterations the loss is 0.590698, the accuracy is 0.804688
# ###################################
# validation! after 1200 iterations the loss is 0.825357, the accuracy is 0.7086
# training! after 1200 iterations the loss is 0.728444, the accuracy is 0.742188
# ###################################
# validation! after 1300 iterations the loss is 0.779832, the accuracy is 0.7334
# training! after 1300 iterations the loss is 0.655052, the accuracy is 0.757812
# ###################################
# validation! after 1400 iterations the loss is 0.745045, the accuracy is 0.736
# training! after 1400 iterations the loss is 0.475538, the accuracy is 0.835938
# ###################################
# validation! after 1500 iterations the loss is 0.786779, the accuracy is 0.7206
# training! after 1500 iterations the loss is 0.483478, the accuracy is 0.8125
# ###################################
# validation! after 1600 iterations the loss is 0.749663, the accuracy is 0.7454
# training! after 1600 iterations the loss is 0.487244, the accuracy is 0.804688
# ###################################
# validation! after 1700 iterations the loss is 0.721215, the accuracy is 0.7474
# training! after 1700 iterations the loss is 0.404752, the accuracy is 0.835938
# ###################################
# validation! after 1800 iterations the loss is 0.722593, the accuracy is 0.752
# training! after 1800 iterations the loss is 0.36923, the accuracy is 0.898438
# ###################################
# validation! after 1900 iterations the loss is 0.712153, the accuracy is 0.752
# training! after 1900 iterations the loss is 0.322246, the accuracy is 0.875
# ###################################
# validation! after 2000 iterations the loss is 0.69376, the accuracy is 0.7618
# training! after 2000 iterations the loss is 0.382857, the accuracy is 0.890625
# ###################################
# validation! after 2100 iterations the loss is 0.704001, the accuracy is 0.7564
# training! after 2100 iterations the loss is 0.388511, the accuracy is 0.890625
# ###################################
# validation! after 2200 iterations the loss is 0.711723, the accuracy is 0.7628
# training! after 2200 iterations the loss is 0.509073, the accuracy is 0.867188
# ###################################
# validation! after 2300 iterations the loss is 0.738798, the accuracy is 0.7516
# training! after 2300 iterations the loss is 0.372289, the accuracy is 0.875
# ###################################
# validation! after 2400 iterations the loss is 0.703049, the accuracy is 0.7598
# training! after 2400 iterations the loss is 0.352485, the accuracy is 0.875
# ###################################
# validation! after 2500 iterations the loss is 0.68149, the accuracy is 0.7668
# training! after 2500 iterations the loss is 0.460476, the accuracy is 0.835938
# ###################################
# validation! after 2600 iterations the loss is 0.684134, the accuracy is 0.77
# training! after 2600 iterations the loss is 0.344776, the accuracy is 0.882812
# ###################################
# validation! after 2700 iterations the loss is 0.672355, the accuracy is 0.7748
# training! after 2700 iterations the loss is 0.17971, the accuracy is 0.953125
# ###################################
# validation! after 2800 iterations the loss is 0.687967, the accuracy is 0.7714
# training! after 2800 iterations the loss is 0.354209, the accuracy is 0.890625
# ###################################
# validation! after 2900 iterations the loss is 0.673115, the accuracy is 0.7748
# training! after 2900 iterations the loss is 0.374808, the accuracy is 0.851562
# ###################################
# validation! after 3000 iterations the loss is 0.671789, the accuracy is 0.7762
# training! after 3000 iterations the loss is 0.296802, the accuracy is 0.921875
# ###################################
# validation! after 3100 iterations the loss is 0.723672, the accuracy is 0.7646
# training! after 3100 iterations the loss is 0.53305, the accuracy is 0.835938
# ###################################
# validation! after 3200 iterations the loss is 0.689664, the accuracy is 0.773
# training! after 3200 iterations the loss is 0.155526, the accuracy is 0.953125
# ###################################
# validation! after 3300 iterations the loss is 0.651198, the accuracy is 0.7866
# training! after 3300 iterations the loss is 0.349681, the accuracy is 0.898438
# ###################################
# validation! after 3400 iterations the loss is 0.702799, the accuracy is 0.767
# training! after 3400 iterations the loss is 0.129853, the accuracy is 0.96875
# ###################################
# validation! after 3500 iterations the loss is 0.675529, the accuracy is 0.7798
# training! after 3500 iterations the loss is 0.242813, the accuracy is 0.914062
# ###################################
# validation! after 3600 iterations the loss is 0.664744, the accuracy is 0.781
# training! after 3600 iterations the loss is 0.286244, the accuracy is 0.914062
# ###################################
# validation! after 3700 iterations the loss is 0.664333, the accuracy is 0.7822
# training! after 3700 iterations the loss is 0.153359, the accuracy is 0.9375
# ###################################
# validation! after 3800 iterations the loss is 0.684096, the accuracy is 0.7836
# training! after 3800 iterations the loss is 0.0971517, the accuracy is 0.96875
# ###################################
# validation! after 3900 iterations the loss is 0.735142, the accuracy is 0.773
# training! after 3900 iterations the loss is 0.25871, the accuracy is 0.90625
# ###################################
# validation! after 4000 iterations the loss is 0.684459, the accuracy is 0.7784
# training! after 4000 iterations the loss is 0.122497, the accuracy is 0.960938
# ###################################
# validation! after 4100 iterations the loss is 0.695167, the accuracy is 0.782
# training! after 4100 iterations the loss is 0.141094, the accuracy is 0.960938
# ###################################
# validation! after 4200 iterations the loss is 0.681399, the accuracy is 0.7874
# training! after 4200 iterations the loss is 0.167935, the accuracy is 0.953125
# ###################################
# validation! after 4300 iterations the loss is 0.681761, the accuracy is 0.7882
# training! after 4300 iterations the loss is 0.115651, the accuracy is 0.976562
# ###################################
# validation! after 4400 iterations the loss is 0.687268, the accuracy is 0.7918
# training! after 4400 iterations the loss is 0.135977, the accuracy is 0.960938
# ###################################
# validation! after 4500 iterations the loss is 0.700768, the accuracy is 0.7846
# training! after 4500 iterations the loss is 0.196186, the accuracy is 0.945312
# ###################################
# validation! after 4600 iterations the loss is 0.668368, the accuracy is 0.7886
# training! after 4600 iterations the loss is 0.13596, the accuracy is 0.953125
# ###################################
# validation! after 4700 iterations the loss is 0.697996, the accuracy is 0.7844
# training! after 4700 iterations the loss is 0.118489, the accuracy is 0.960938
# ###################################
# validation! after 4800 iterations the loss is 0.684302, the accuracy is 0.7852
# training! after 4800 iterations the loss is 0.171062, the accuracy is 0.945312
# ###################################
# validation! after 4900 iterations the loss is 0.681306, the accuracy is 0.79
# training! after 4900 iterations the loss is 0.0645203, the accuracy is 0.976562
# ###################################
# validation! after 5000 iterations the loss is 0.686699, the accuracy is 0.7876
# training! after 5000 iterations the loss is 0.134615, the accuracy is 0.960938
# ###################################
# validation! after 5100 iterations the loss is 0.716968, the accuracy is 0.786
# training! after 5100 iterations the loss is 0.0662731, the accuracy is 0.984375
# ###################################
# validation! after 5200 iterations the loss is 0.681473, the accuracy is 0.7894
# training! after 5200 iterations the loss is 0.0589456, the accuracy is 1.0
# ###################################
# validation! after 5300 iterations the loss is 0.668442, the accuracy is 0.7928
# training! after 5300 iterations the loss is 0.0820452, the accuracy is 0.976562
# ###################################
# validation! after 5400 iterations the loss is 0.707564, the accuracy is 0.7926
# training! after 5400 iterations the loss is 0.128936, the accuracy is 0.96875
# ###################################
# validation! after 5500 iterations the loss is 0.687776, the accuracy is 0.7944
# training! after 5500 iterations the loss is 0.097006, the accuracy is 0.960938
# ###################################
# validation! after 5600 iterations the loss is 0.734056, the accuracy is 0.78
# training! after 5600 iterations the loss is 0.171247, the accuracy is 0.929688
# ###################################
# validation! after 5700 iterations the loss is 0.694914, the accuracy is 0.794
# training! after 5700 iterations the loss is 0.0339853, the accuracy is 1.0
# ###################################
# validation! after 5800 iterations the loss is 0.698632, the accuracy is 0.7916
# training! after 5800 iterations the loss is 0.031614, the accuracy is 1.0
# ###################################
# validation! after 5900 iterations the loss is 0.737182, the accuracy is 0.7912
# training! after 5900 iterations the loss is 0.112802, the accuracy is 0.960938

# %%
save_predictions('ans2-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans2-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
# Out:
# (10, 10000)
# array([[ -2.07462335,   5.98183823,   3.44229984, ...,  -4.13653469,
#           2.89506269,  -8.66244316],
#        [ -1.76037085,  12.56741905,  -4.42907667, ...,  -6.14924908,
#           7.25259495, -11.99969006],
#        [ -2.21564674,  -7.40246391,   1.54524112, ...,   4.15086126,
#           0.539554  ,  -1.36715853],
#        ...,
#        [ -1.2539717 , -11.40724182,   0.99441135, ...,   4.50973558,
#          -1.79880798,  18.51285934],
#        [ -2.6909461 ,  15.32911205,  -0.11396468, ...,  -5.40692949,
#          -2.11565709,  -8.85854053],
#        [ -1.06548655,   0.87547415,  -2.57215023, ...,  -5.48661661,
#           2.51511073, -10.11819172]], dtype=float32)
