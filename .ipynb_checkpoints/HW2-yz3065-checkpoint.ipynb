# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'horse': 7, 'airplane': 0, 'truck': 9, 'deer': 4, 'cat': 3, 'ship': 8, 'automobile': 1, 'bird': 2, 'dog': 5, 'frog': 6}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# Loaded 10000/10000
# Data loading done

# %%
print(X_validation.shape)
print(X_test.shape)
arr = np.arange(X_train.shape[0])
np.random.shuffle(arr)
print(arr)
# Out:
# (5000, 3072)
# (10000, 3072)
# [21957 22986  2325 ...,  8624    39 31094]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[0]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary6'
iteration = 20000
batch_size = 128
learning_rate = 0.01

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
def save_variable(var, name):
    with tf.name_scope(name) as scope:
        mean = tf.reduce_mean(var)
        tf.summary.scalar('mean', mean)
        stddev = tf.sqrt(tf.reduce_mean(var - mean))
        tf.summary.scalar('stddev', stddev)
        tf.summary.histogram('histgram', var)

# %%
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1')
#         weight1 = tf.contrib.layers.flatten(tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1'))
        weight1 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv1')[0]
        batch_norm1 = tf.layers.batch_normalization(conv1, axis = 1, name='batch_norm1')
        dropout1 = tf.layers.dropout(batch_norm1,rate=0.1, training=training, name='dropout1')
        pool1 = tf.layers.max_pooling2d(inputs=dropout1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=pool1, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv2')
        weight2 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv2')[0]
        batch_norm2 = tf.layers.batch_normalization(conv2, axis = 1, name='batch_norm2')
        dropout2 = tf.layers.dropout(batch_norm2,rate=0.2, training=training, name='dropout2')
        pool2 = tf.layers.max_pooling2d(inputs=dropout2, pool_size=2, strides=2, padding='SAME', name='pool2')  
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=pool2, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv3')
        weight3 = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'conv3')[0]
        batch_norm3 = tf.layers.batch_normalization(conv3, axis = 1, name='batch_norm3')
        dropout3 = tf.layers.dropout(batch_norm3,rate=0.2, training=training, name='dropout3')
        pool3 = tf.layers.max_pooling2d(inputs=dropout3, pool_size=2, strides=2, padding='SAME', name='pool3')

    with tf.name_scope('fc') as scope:
        pool3_flat = tf.reshape(pool3, [-1, 4*4*128], name='pool3_flat')
        dropout_fc1 = tf.layers.dropout(pool3_flat, rate=0.2, training=training, name='dropout_fc1')
        
        dense1 = tf.layers.dense(dropout_fc1, units = 8*128, activation = tf.nn.relu, name='dense1')
        batch_norm4 = tf.layers.batch_normalization(dense1, axis = 1, name='batch_norm4')
        dropout_fc2 = tf.layers.dropout(batch_norm4, rate=0.2, training=training, name='dropout_fc2')
        
        dense2 = tf.layers.dense(dropout_fc2, units = 128, activation = tf.nn.relu, name='dense2') 
        batch_norm5 = tf.layers.batch_normalization(dense2, axis = 1, name='batch_norm5')
        dropout_fc3 = tf.layers.dropout(batch_norm5, rate=0.2, training=training, name='dropout_fc3')


    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout_fc3, units = 10, name='logits')
        weight_logits = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, 'logits')[0]

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))
     
    with tf.name_scope('summary') as scope:
        save_variable(weight1,'weight1')
        save_variable(weight2,'weight2')
        save_variable(weight3,'weight3')
        save_variable(weight_logits,'weight_logits')
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
print(weight_logits)
# Out:
# <tf.Variable 'logits/kernel:0' shape=(128, 10) dtype=float32_ref>

# %%
def train(X_train, y_train, X_validation, y_validation, iteration, X_test):

    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
            
        y_labels = logits.eval(feed_dict={X: X_test, dropout_rate:0.3, training:False})
    return y_labels.T

# %%
y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.30607, the accuracy is 0.0864
# training! after 0 iterations the loss is 2.30874, the accuracy is 0.109375
# ###################################
# validation! after 100 iterations the loss is 2.29634, the accuracy is 0.114
# training! after 100 iterations the loss is 2.29359, the accuracy is 0.117188
# ###################################
# validation! after 200 iterations the loss is 2.28808, the accuracy is 0.156
# training! after 200 iterations the loss is 2.28598, the accuracy is 0.132812
# ###################################
# validation! after 300 iterations the loss is 2.26717, the accuracy is 0.18
# training! after 300 iterations the loss is 2.27636, the accuracy is 0.1875
# ###################################
# validation! after 400 iterations the loss is 2.25043, the accuracy is 0.1638
# training! after 400 iterations the loss is 2.25254, the accuracy is 0.148438
# ###################################
# validation! after 500 iterations the loss is 2.21987, the accuracy is 0.1736
# training! after 500 iterations the loss is 2.2279, the accuracy is 0.164062
# ###################################
# validation! after 600 iterations the loss is 2.17723, the accuracy is 0.2482
# training! after 600 iterations the loss is 2.1882, the accuracy is 0.28125
# ###################################
# validation! after 700 iterations the loss is 2.2024, the accuracy is 0.2022
# training! after 700 iterations the loss is 2.20704, the accuracy is 0.203125
# ###################################
# validation! after 800 iterations the loss is 2.17755, the accuracy is 0.2026
# training! after 800 iterations the loss is 2.18992, the accuracy is 0.234375
# ###################################
# validation! after 900 iterations the loss is 2.1633, the accuracy is 0.2206
# training! after 900 iterations the loss is 2.15135, the accuracy is 0.273438
# ###################################
# validation! after 1000 iterations the loss is 2.22696, the accuracy is 0.1636
# training! after 1000 iterations the loss is 2.21917, the accuracy is 0.179688
# ###################################
# validation! after 1100 iterations the loss is 2.08458, the accuracy is 0.2882
# training! after 1100 iterations the loss is 2.06933, the accuracy is 0.3125
# ###################################
# validation! after 1200 iterations the loss is 2.10504, the accuracy is 0.2542
# training! after 1200 iterations the loss is 2.08386, the accuracy is 0.28125
# ###################################
# validation! after 1300 iterations the loss is 2.04421, the accuracy is 0.3076
# training! after 1300 iterations the loss is 2.04929, the accuracy is 0.265625
# ###################################
# validation! after 1400 iterations the loss is 2.04786, the accuracy is 0.3008
# training! after 1400 iterations the loss is 2.08115, the accuracy is 0.335938
# ###################################
# validation! after 1500 iterations the loss is 2.13906, the accuracy is 0.1994
# training! after 1500 iterations the loss is 2.14909, the accuracy is 0.226562
# ###################################
# validation! after 1600 iterations the loss is 2.03629, the accuracy is 0.2906
# training! after 1600 iterations the loss is 2.05331, the accuracy is 0.34375
# ###################################
# validation! after 1700 iterations the loss is 2.01746, the accuracy is 0.2932
# training! after 1700 iterations the loss is 1.98213, the accuracy is 0.398438
# ###################################
# validation! after 1800 iterations the loss is 1.98527, the accuracy is 0.3132
# training! after 1800 iterations the loss is 1.93768, the accuracy is 0.359375
# ###################################
# validation! after 1900 iterations the loss is 1.89752, the accuracy is 0.3724
# training! after 1900 iterations the loss is 1.88865, the accuracy is 0.390625
# ###################################
# validation! after 2000 iterations the loss is 1.96769, the accuracy is 0.3172
# training! after 2000 iterations the loss is 1.95709, the accuracy is 0.328125
# ###################################
# validation! after 2100 iterations the loss is 1.88351, the accuracy is 0.367
# training! after 2100 iterations the loss is 1.91096, the accuracy is 0.351562
# ###################################
# validation! after 2200 iterations the loss is 1.91516, the accuracy is 0.3242
# training! after 2200 iterations the loss is 1.92712, the accuracy is 0.296875
# ###################################
# validation! after 2300 iterations the loss is 1.95878, the accuracy is 0.2982
# training! after 2300 iterations the loss is 1.8475, the accuracy is 0.429688
# ###################################
# validation! after 2400 iterations the loss is 1.90823, the accuracy is 0.3362
# training! after 2400 iterations the loss is 1.92634, the accuracy is 0.289062
# ###################################
# validation! after 2500 iterations the loss is 1.84426, the accuracy is 0.3708
# training! after 2500 iterations the loss is 1.88788, the accuracy is 0.34375
# ###################################
# validation! after 2600 iterations the loss is 1.86155, the accuracy is 0.3486
# training! after 2600 iterations the loss is 1.76487, the accuracy is 0.5
# ###################################
# validation! after 2700 iterations the loss is 1.878, the accuracy is 0.336
# training! after 2700 iterations the loss is 1.79227, the accuracy is 0.375
# ###################################
# validation! after 2800 iterations the loss is 1.90832, the accuracy is 0.3156
# training! after 2800 iterations the loss is 1.87329, the accuracy is 0.335938
# ###################################
# validation! after 2900 iterations the loss is 1.86912, the accuracy is 0.3222
# training! after 2900 iterations the loss is 1.87471, the accuracy is 0.3125
# ###################################
# validation! after 3000 iterations the loss is 1.88552, the accuracy is 0.3272
# training! after 3000 iterations the loss is 1.97095, the accuracy is 0.320312
# ###################################
# validation! after 3100 iterations the loss is 1.79128, the accuracy is 0.3746
# training! after 3100 iterations the loss is 1.8318, the accuracy is 0.414062
# ###################################
# validation! after 3200 iterations the loss is 1.82018, the accuracy is 0.3578
# training! after 3200 iterations the loss is 1.82302, the accuracy is 0.359375
# ###################################
# validation! after 3300 iterations the loss is 1.8386, the accuracy is 0.3472
# training! after 3300 iterations the loss is 1.82392, the accuracy is 0.359375
# ###################################
# validation! after 3400 iterations the loss is 1.89024, the accuracy is 0.327
# training! after 3400 iterations the loss is 1.83245, the accuracy is 0.367188
# ###################################
# validation! after 3500 iterations the loss is 1.74379, the accuracy is 0.3926
# training! after 3500 iterations the loss is 1.75319, the accuracy is 0.390625
# ###################################
# validation! after 3600 iterations the loss is 1.78063, the accuracy is 0.3626
# training! after 3600 iterations the loss is 1.74231, the accuracy is 0.414062
# ###################################
# validation! after 3700 iterations the loss is 1.73433, the accuracy is 0.3726
# training! after 3700 iterations the loss is 1.75107, the accuracy is 0.335938
# ###################################
# validation! after 3800 iterations the loss is 1.88725, the accuracy is 0.3022
# training! after 3800 iterations the loss is 1.7161, the accuracy is 0.40625
# ###################################
# validation! after 3900 iterations the loss is 1.67631, the accuracy is 0.396
# training! after 3900 iterations the loss is 1.63921, the accuracy is 0.429688
# ###################################
# validation! after 4000 iterations the loss is 1.74961, the accuracy is 0.3706
# training! after 4000 iterations the loss is 1.73607, the accuracy is 0.359375
# ###################################
# validation! after 4100 iterations the loss is 1.7223, the accuracy is 0.3678
# training! after 4100 iterations the loss is 1.55475, the accuracy is 0.476562
# ###################################
# validation! after 4200 iterations the loss is 1.68685, the accuracy is 0.3912
# training! after 4200 iterations the loss is 1.76812, the accuracy is 0.328125
# ###################################
# validation! after 4300 iterations the loss is 1.71677, the accuracy is 0.361
# training! after 4300 iterations the loss is 1.67072, the accuracy is 0.320312
# ###################################
# validation! after 4400 iterations the loss is 1.68318, the accuracy is 0.3952
# training! after 4400 iterations the loss is 1.6913, the accuracy is 0.367188
# ###################################
# validation! after 4500 iterations the loss is 1.67707, the accuracy is 0.3838
# training! after 4500 iterations the loss is 1.71512, the accuracy is 0.421875
# ###################################
# validation! after 4600 iterations the loss is 1.67174, the accuracy is 0.39
# training! after 4600 iterations the loss is 1.6195, the accuracy is 0.460938
# ###################################
# validation! after 4700 iterations the loss is 1.6804, the accuracy is 0.3824
# training! after 4700 iterations the loss is 1.67541, the accuracy is 0.40625
# ###################################
# validation! after 4800 iterations the loss is 1.63269, the accuracy is 0.4168
# training! after 4800 iterations the loss is 1.68341, the accuracy is 0.382812
# ###################################
# validation! after 4900 iterations the loss is 1.64104, the accuracy is 0.3824
# training! after 4900 iterations the loss is 1.6551, the accuracy is 0.390625
# ###################################
# validation! after 5000 iterations the loss is 1.75259, the accuracy is 0.353
# training! after 5000 iterations the loss is 1.65485, the accuracy is 0.375
# ###################################
# validation! after 5100 iterations the loss is 1.73496, the accuracy is 0.369
# training! after 5100 iterations the loss is 1.713, the accuracy is 0.375
# ###################################
# validation! after 5200 iterations the loss is 1.70193, the accuracy is 0.3668
# training! after 5200 iterations the loss is 1.64825, the accuracy is 0.414062
# ###################################
# validation! after 5300 iterations the loss is 1.63063, the accuracy is 0.394
# training! after 5300 iterations the loss is 1.71349, the accuracy is 0.3125
# ###################################
# validation! after 5400 iterations the loss is 1.69788, the accuracy is 0.3724
# training! after 5400 iterations the loss is 1.60516, the accuracy is 0.382812
# ###################################
# validation! after 5500 iterations the loss is 1.7131, the accuracy is 0.366
# training! after 5500 iterations the loss is 1.75188, the accuracy is 0.34375
# ###################################
# validation! after 5600 iterations the loss is 1.67828, the accuracy is 0.37
# training! after 5600 iterations the loss is 1.68589, the accuracy is 0.414062
# ###################################
# validation! after 5700 iterations the loss is 1.7036, the accuracy is 0.3562
# training! after 5700 iterations the loss is 1.66086, the accuracy is 0.382812
# ###################################
# validation! after 5800 iterations the loss is 1.63979, the accuracy is 0.385
# training! after 5800 iterations the loss is 1.58847, the accuracy is 0.40625
# ###################################
# validation! after 5900 iterations the loss is 1.7346, the accuracy is 0.3542
# training! after 5900 iterations the loss is 1.59726, the accuracy is 0.382812
# ###################################
# validation! after 6000 iterations the loss is 1.60832, the accuracy is 0.4036
# training! after 6000 iterations the loss is 1.58257, the accuracy is 0.484375
# ###################################
# validation! after 6100 iterations the loss is 1.57789, the accuracy is 0.4244
# training! after 6100 iterations the loss is 1.58508, the accuracy is 0.367188
# ###################################
# validation! after 6200 iterations the loss is 1.65216, the accuracy is 0.3916
# training! after 6200 iterations the loss is 1.5377, the accuracy is 0.429688
# ###################################
# validation! after 6300 iterations the loss is 1.55564, the accuracy is 0.4258
# training! after 6300 iterations the loss is 1.48242, the accuracy is 0.429688
# ###################################
# validation! after 6400 iterations the loss is 1.58163, the accuracy is 0.4022
# training! after 6400 iterations the loss is 1.56469, the accuracy is 0.40625
# ###################################
# validation! after 6500 iterations the loss is 1.6012, the accuracy is 0.3874
# training! after 6500 iterations the loss is 1.5306, the accuracy is 0.421875
# ###################################
# validation! after 6600 iterations the loss is 1.61447, the accuracy is 0.3846
# training! after 6600 iterations the loss is 1.44477, the accuracy is 0.429688
# ###################################
# validation! after 6700 iterations the loss is 1.62853, the accuracy is 0.3926
# training! after 6700 iterations the loss is 1.69229, the accuracy is 0.390625
# ###################################
# validation! after 6800 iterations the loss is 1.55245, the accuracy is 0.4146
# training! after 6800 iterations the loss is 1.44384, the accuracy is 0.460938
# ###################################
# validation! after 6900 iterations the loss is 1.55458, the accuracy is 0.4348
# training! after 6900 iterations the loss is 1.48255, the accuracy is 0.453125
# ###################################
# validation! after 7000 iterations the loss is 1.56506, the accuracy is 0.418
# training! after 7000 iterations the loss is 1.51065, the accuracy is 0.46875
# ###################################
# validation! after 7100 iterations the loss is 1.56762, the accuracy is 0.4054
# training! after 7100 iterations the loss is 1.61654, the accuracy is 0.40625
# ###################################
# validation! after 7200 iterations the loss is 1.53323, the accuracy is 0.4214
# training! after 7200 iterations the loss is 1.53206, the accuracy is 0.367188
# ###################################
# validation! after 7300 iterations the loss is 1.63149, the accuracy is 0.3962
# training! after 7300 iterations the loss is 1.61697, the accuracy is 0.382812
# ###################################
# validation! after 7400 iterations the loss is 1.57723, the accuracy is 0.4158
# training! after 7400 iterations the loss is 1.65244, the accuracy is 0.351562
# ###################################
# validation! after 7500 iterations the loss is 1.6394, the accuracy is 0.3834
# training! after 7500 iterations the loss is 1.47208, the accuracy is 0.460938
# ###################################
# validation! after 7600 iterations the loss is 1.49829, the accuracy is 0.434
# training! after 7600 iterations the loss is 1.51794, the accuracy is 0.421875
# ###################################
# validation! after 7700 iterations the loss is 1.57631, the accuracy is 0.4212
# training! after 7700 iterations the loss is 1.47794, the accuracy is 0.445312
# ###################################
# validation! after 7800 iterations the loss is 1.6282, the accuracy is 0.4002
# training! after 7800 iterations the loss is 1.70143, the accuracy is 0.390625
# ###################################
# validation! after 7900 iterations the loss is 1.50501, the accuracy is 0.4406
# training! after 7900 iterations the loss is 1.47742, the accuracy is 0.476562
# ###################################
# validation! after 8000 iterations the loss is 1.45664, the accuracy is 0.4682
# training! after 8000 iterations the loss is 1.42412, the accuracy is 0.5
# ###################################
# validation! after 8100 iterations the loss is 1.61345, the accuracy is 0.4016
# training! after 8100 iterations the loss is 1.38309, the accuracy is 0.476562
# ###################################
# validation! after 8200 iterations the loss is 1.48787, the accuracy is 0.4372
# training! after 8200 iterations the loss is 1.60794, the accuracy is 0.421875
# ###################################
# validation! after 8300 iterations the loss is 1.49664, the accuracy is 0.4426
# training! after 8300 iterations the loss is 1.44946, the accuracy is 0.476562
# ###################################
# validation! after 8400 iterations the loss is 1.59728, the accuracy is 0.4066
# training! after 8400 iterations the loss is 1.61045, the accuracy is 0.40625
# ###################################
# validation! after 8500 iterations the loss is 1.52878, the accuracy is 0.4346
# training! after 8500 iterations the loss is 1.40122, the accuracy is 0.460938
# ###################################
# validation! after 8600 iterations the loss is 1.50199, the accuracy is 0.4526
# training! after 8600 iterations the loss is 1.48423, the accuracy is 0.398438
# ###################################
# validation! after 8700 iterations the loss is 1.51297, the accuracy is 0.445
# training! after 8700 iterations the loss is 1.35888, the accuracy is 0.515625
# ###################################
# validation! after 8800 iterations the loss is 1.44477, the accuracy is 0.4608
# training! after 8800 iterations the loss is 1.42834, the accuracy is 0.492188
# ###################################
# validation! after 8900 iterations the loss is 1.60625, the accuracy is 0.4098
# training! after 8900 iterations the loss is 1.4209, the accuracy is 0.4375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-65502cacbabb> in <module>()
# ----> 1 y_predicted = train(X_train, y_train, X_validation, y_validation, iteration, X_test)
#
# <ipython-input-12-2081c85362cd> in train(X_train, y_train, X_validation, y_validation, iteration, X_test)
#       8         for step in range(iteration):
#       9             X_batch, y_batch = get_batch(X_train, y_train, batch_size)
# ---> 10             sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
#      11
#      12             if step % 100 == 0:
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# save_predictions('ans1-yz3065', y_predicted)

# %%
# test if your numpy file has been saved correctly
loaded_y = np.load('ans1-yz3065.npy')
print(loaded_y.shape)
loaded_y[:10]
