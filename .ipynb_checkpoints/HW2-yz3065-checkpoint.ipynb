# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import scipy.misc
import glob
import sys
import tensorflow as tf
from datetime import datetime

# %%
# Helper functions, DO NOT modify this

def get_img_array(path):
    """
    Given path of image, returns it's numpy array
    """
    return scipy.misc.imread(path)

def get_files(folder):
    """
    Given path to folder, returns list of files in it
    """
    filenames = [file for file in glob.glob(folder+'*/*')]
    filenames.sort()
    return filenames

def get_label(filepath, label2id):
    """
    Files are assumed to be labeled as: /path/to/file/999_frog.png
    Returns label for a filepath
    """
    tokens = filepath.split('/')
    label = tokens[-1].split('_')[1][:-4]
    if label in label2id:
        return label2id[label]
    else:
        sys.exit("Invalid label: " + label)

# %%
# Functions to load data, DO NOT change these

def get_labels(folder, label2id):
    """
    Returns vector of labels extracted from filenames of all files in folder
    :param folder: path to data folder
    :param label2id: mapping of text labels to numeric ids. (Eg: automobile -> 0)
    """
    files = get_files(folder)
    y = []
    for f in files:
        y.append(get_label(f,label2id))
    return np.array(y)

def one_hot(y, num_classes=10):
    """
    Converts each label index in y to vector with one_hot encoding
    """
    y_one_hot = np.zeros((y.shape[0], num_classes))
    y_one_hot[y] = 1
    return y_one_hot.T

def get_label_mapping(label_file):
    """
    Returns mappings of label to index and index to label
    The input file has list of labels, each on a separate line.
    """
    with open(label_file, 'r') as f:
        id2label = f.readlines()
        id2label = [l.strip() for l in id2label]
    label2id = {}
    count = 0
    for label in id2label:
        label2id[label] = count
        count += 1
    return id2label, label2id

def get_images(folder):
    """
    returns numpy array of all samples in folder
    each column is a sample resized to 30x30 and flattened
    """
    files = get_files(folder)
    images = []
    count = 0
    
    for f in files:
        count += 1
        if count % 10000 == 0:
            print("Loaded {}/{}".format(count,len(files)))
        img_arr = get_img_array(f)
        img_arr = img_arr.flatten() / 255.0
        images.append(img_arr)
    X = np.column_stack(images)

    return X

def get_train_data(data_root_path):
    """
    Return X and y
    """
    train_data_path = data_root_path + 'train'
    id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
    print(label2id)
    X = get_images(train_data_path)
    y = get_labels(train_data_path, label2id)
    return X, y

def save_predictions(filename, y):
    """
    Dumps y into .npy file
    """
    np.save(filename, y)# Load the data

# %%
# Load the data
data_root_path = '/home/ec2-user/Neural_Network/cifar10-hw1/'
X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
X_test = get_images(data_root_path + 'test').T

print('Data loading done')
indexs = np.random.choice(50000, 5000, replace=False)
X_validation = X_train[:,indexs].T
y_validation = y_train[indexs]
X_train = np.delete(X_train,indexs, axis = 1).T
y_train = np.delete(y_train,indexs)
# Out:
# {'deer': 4, 'ship': 8, 'airplane': 0, 'truck': 9, 'automobile': 1, 'horse': 7, 'bird': 2, 'cat': 3, 'dog': 5, 'frog': 6}
# Loaded 10000/50000
# Loaded 20000/50000
# Loaded 30000/50000
# Loaded 40000/50000
# Loaded 50000/50000
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-10-6c892e61400d> in <module>()
#       1 # Load the data
#       2 data_root_path = '/home/ec2-user/Neural_Network/cifar10-hw1/'
# ----> 3 X_train, y_train = get_train_data(data_root_path) # this may take a few minutes
#       4 X_test = get_images(data_root_path + 'test').T
#       5
#
# <ipython-input-9-4cd906bb9748> in get_train_data(data_root_path)
#      63     id2label, label2id = get_label_mapping(data_root_path+'labels.txt')
#      64     print(label2id)
# ---> 65     X = get_images(train_data_path)
#      66     y = get_labels(train_data_path, label2id)
#      67     return X, y
#
# <ipython-input-9-4cd906bb9748> in get_images(folder)
#      52         img_arr = img_arr.flatten() / 255.0
#      53         images.append(img_arr)
# ---> 54     X = np.column_stack(images)
#      55
#      56     return X
#
# /usr/lib64/python3.4/dist-packages/numpy/lib/shape_base.py in column_stack(tup)
#     351             arr = array(arr, copy=False, subok=True, ndmin=2).T
#     352         arrays.append(arr)
# --> 353     return _nx.concatenate(arrays, 1)
#     354
#     355 def dstack(tup):
#
# MemoryError:

# %%
print(X_validation.shape)
print(X_test.shape)
shit = np.array([[1,2,4],[4,2,1]])
arr = np.arange(10)
shuffle = np.random.shuffle(arr)
print(arr)
# Out:
# [8 9 3 7 1 6 0 4 5 2]

# %%
def get_batch(X, y, batch_size):
        """
        Return minibatch of samples and labels
        
        :param X, y: samples and corresponding labels
        :parma batch_size: minibatch size
        :returns: (tuple) X_batch, y_batch
        """
        m = X.shape[1]
        start_index = np.random.randint(0, m - batch_size)
        X_batch = X[start_index:(start_index + batch_size), :]
        y_batch = y[start_index:(start_index + batch_size)]
        
        return X_batch, y_batch

# %%
logdir = 'tf_logs/summary7'
iteration = 20000
batch_size = 128
learning_rate = 0.001

# %%
# try use a function to create a layer
# def create_conv(filters, input_layer):
#     conv = tf.layers.conv2d(inputs=input_layer, filters=filters, kernel_size=3, strides=1, 
#                                     padding = 'SAME', activation = tf.nn.relu, name='conv')
#     pool = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool')
#     return pool

# %%
with tf.device('/gpu:0'):
    with tf.name_scope('input') as scope:
        X = tf.placeholder(tf.float32, shape = (None, 3072))
        y = tf.placeholder(tf.int32, shape = (None))
        dropout_rate = tf.placeholder(tf.float32, shape=())
        training = tf.placeholder(tf.bool)
        input_layer = tf.reshape(X, [-1, 32, 32, 3])

    with tf.name_scope('conv1') as scope:
        conv1 = tf.layers.conv2d(inputs=input_layer, filters=64, kernel_size=3, strides=1, 
                                padding = 'SAME', activation = tf.nn.relu, name='conv1')
        pool1 = tf.layers.max_pooling2d(inputs=conv1, pool_size=2, strides=2, padding='SAME', name='pool1')

    with tf.name_scope('conv2') as scope:
        conv2 = tf.layers.conv2d(inputs=pool1, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv2')
        pool2 = tf.layers.max_pooling2d(inputs=conv2, pool_size=2, strides=2, padding='SAME', name='pool2')
        
    with tf.name_scope('conv3') as scope:
        conv3 = tf.layers.conv2d(inputs=pool2, filters=128, kernel_size=3, strides=1, 
                            padding = 'SAME', activation = tf.nn.relu, name='conv3')
        pool3 = tf.layers.max_pooling2d(inputs=conv3, pool_size=2, strides=2, padding='SAME', name='pool3')

    with tf.name_scope('fc') as scope:
        pool3_flat = tf.reshape(pool3, [-1, 4*4*128], name='pool3_flat')
        dropout1 = tf.layers.dropout(pool3_flat, rate=dropout_rate, training=training, name='dropout1')
        dense1 = tf.layers.dense(dropout1, units = 8*128, activation = tf.nn.relu, name='dense1')
        dropout2 = tf.layers.dropout(dense1, rate=dropout_rate, training=training, name='dropout2')
        dense2 = tf.layers.dense(dropout2, units = 128, activation = tf.nn.relu, name='dense2')
        dropout3 = tf.layers.dropout(dense2, rate=dropout_rate, training=training, name='dropout3')

    with tf.name_scope('logits') as scope:
        logits = tf.layers.dense(dropout3, units = 10, name='logits')

    with tf.name_scope('loss') as scope:
        softmax = tf.nn.sparse_softmax_cross_entropy_with_logits(labels=y, logits=logits, name = 'softmax')
        loss = tf.reduce_mean(softmax) 

    with tf.name_scope('train') as scope:
        optimizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss)

    with tf.name_scope('eval') as scope:
        correct = tf.nn.in_top_k(logits, y, 1)
        accuracy = tf.reduce_mean(tf.cast(correct, tf.float32))

    with tf.name_scope('summary') as scope:
        tf.summary.scalar('loss', loss)
        tf.summary.scalar('accuracy', accuracy)
        
        merged = tf.summary.merge_all()
        train_writer = tf.summary.FileWriter(logdir + '/train', tf.get_default_graph())
        test_writer = tf.summary.FileWriter(logdir + '/test', tf.get_default_graph())

    with tf.name_scope('init') as scope:
        init = tf.global_variables_initializer()

# %%
def train(X_train, y_train, X_validation, y_validation, iteration):
    config = tf.ConfigProto()
    config.allow_soft_placement = True
    
    with tf.Session(config=config) as sess:
        sess.run(init)
        for step in range(iteration):
            X_batch, y_batch = get_batch(X_train, y_train, batch_size)
            sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
                
            if step % 100 == 0:
                summary, loss_, acc = sess.run([merged, loss, accuracy],
                                               feed_dict={X: X_validation, y:y_validation, dropout_rate:0.3, training:False})
                test_writer.add_summary(summary, step)
                print('###################################')
                print('validation! after '+ str(step) + ' iterations' + 
                              ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))
                        
                summary, loss_, acc = sess.run([merged, loss, accuracy], 
                                               feed_dict={X: X_batch, y:y_batch,dropout_rate:0.3, training:False})
                train_writer.add_summary(summary, step)
                        
                print('training! after '+ str(step) + ' iterations' + 
                          ' the loss is ' + str(loss_) + ', the accuracy is ' + str(acc))

# %%
train(X_train, y_train, X_validation, y_validation, iteration)
# Out:
# ###################################
# validation! after 0 iterations the loss is 2.30663, the accuracy is 0.0994
# training! after 0 iterations the loss is 2.30385, the accuracy is 0.140625
# ###################################
# validation! after 100 iterations the loss is 2.30622, the accuracy is 0.1006
# training! after 100 iterations the loss is 2.30801, the accuracy is 0.09375
# ###################################
# validation! after 200 iterations the loss is 2.30582, the accuracy is 0.1018
# training! after 200 iterations the loss is 2.31159, the accuracy is 0.132812
# ###################################
# validation! after 300 iterations the loss is 2.30543, the accuracy is 0.1012
# training! after 300 iterations the loss is 2.30925, the accuracy is 0.109375
# ###################################
# validation! after 400 iterations the loss is 2.30509, the accuracy is 0.1052
# training! after 400 iterations the loss is 2.30456, the accuracy is 0.101562
# ###################################
# validation! after 500 iterations the loss is 2.30476, the accuracy is 0.1068
# training! after 500 iterations the loss is 2.30455, the accuracy is 0.0625
# ###################################
# validation! after 600 iterations the loss is 2.30443, the accuracy is 0.1088
# training! after 600 iterations the loss is 2.30705, the accuracy is 0.0859375
# ###################################
# validation! after 700 iterations the loss is 2.30411, the accuracy is 0.1092
# training! after 700 iterations the loss is 2.3048, the accuracy is 0.125
# ###################################
# validation! after 800 iterations the loss is 2.3038, the accuracy is 0.1094
# training! after 800 iterations the loss is 2.30689, the accuracy is 0.109375
# ###################################
# validation! after 900 iterations the loss is 2.30351, the accuracy is 0.1096
# training! after 900 iterations the loss is 2.30303, the accuracy is 0.109375
# ###################################
# validation! after 1000 iterations the loss is 2.30326, the accuracy is 0.1098
# training! after 1000 iterations the loss is 2.30214, the accuracy is 0.140625
# ###################################
# validation! after 1100 iterations the loss is 2.303, the accuracy is 0.1102
# training! after 1100 iterations the loss is 2.30376, the accuracy is 0.09375
# ###################################
# validation! after 1200 iterations the loss is 2.30271, the accuracy is 0.113
# training! after 1200 iterations the loss is 2.30344, the accuracy is 0.125
# ###################################
# validation! after 1300 iterations the loss is 2.30245, the accuracy is 0.1122
# training! after 1300 iterations the loss is 2.30326, the accuracy is 0.101562
# ###################################
# validation! after 1400 iterations the loss is 2.30221, the accuracy is 0.116
# training! after 1400 iterations the loss is 2.30683, the accuracy is 0.078125
# ###################################
# validation! after 1500 iterations the loss is 2.30197, the accuracy is 0.1168
# training! after 1500 iterations the loss is 2.30216, the accuracy is 0.117188
# ###################################
# validation! after 1600 iterations the loss is 2.30173, the accuracy is 0.118
# training! after 1600 iterations the loss is 2.3059, the accuracy is 0.101562
# ###################################
# validation! after 1700 iterations the loss is 2.3015, the accuracy is 0.1186
# training! after 1700 iterations the loss is 2.30357, the accuracy is 0.09375
# ###################################
# validation! after 1800 iterations the loss is 2.30129, the accuracy is 0.1184
# training! after 1800 iterations the loss is 2.30034, the accuracy is 0.101562
# ###################################
# validation! after 1900 iterations the loss is 2.30108, the accuracy is 0.1192
# training! after 1900 iterations the loss is 2.29831, the accuracy is 0.125
# ###################################
# validation! after 2000 iterations the loss is 2.30088, the accuracy is 0.1208
# training! after 2000 iterations the loss is 2.30185, the accuracy is 0.132812
# ###################################
# validation! after 2100 iterations the loss is 2.30067, the accuracy is 0.1216
# training! after 2100 iterations the loss is 2.29971, the accuracy is 0.125
# ###################################
# validation! after 2200 iterations the loss is 2.30046, the accuracy is 0.1224
# training! after 2200 iterations the loss is 2.30152, the accuracy is 0.09375
# ###################################
# validation! after 2300 iterations the loss is 2.30027, the accuracy is 0.1234
# training! after 2300 iterations the loss is 2.29524, the accuracy is 0.140625
# ###################################
# validation! after 2400 iterations the loss is 2.30008, the accuracy is 0.125
# training! after 2400 iterations the loss is 2.29674, the accuracy is 0.15625
# ###################################
# validation! after 2500 iterations the loss is 2.29989, the accuracy is 0.1266
# training! after 2500 iterations the loss is 2.30033, the accuracy is 0.125
# ###################################
# validation! after 2600 iterations the loss is 2.29971, the accuracy is 0.1262
# training! after 2600 iterations the loss is 2.29925, the accuracy is 0.132812
# ###################################
# validation! after 2700 iterations the loss is 2.29955, the accuracy is 0.1278
# training! after 2700 iterations the loss is 2.30039, the accuracy is 0.140625
# ###################################
# validation! after 2800 iterations the loss is 2.29937, the accuracy is 0.1312
# training! after 2800 iterations the loss is 2.29725, the accuracy is 0.15625
# ###################################
# validation! after 2900 iterations the loss is 2.2992, the accuracy is 0.1358
# training! after 2900 iterations the loss is 2.29619, the accuracy is 0.148438
# ###################################
# validation! after 3000 iterations the loss is 2.29902, the accuracy is 0.139
# training! after 3000 iterations the loss is 2.29937, the accuracy is 0.148438
# ###################################
# validation! after 3100 iterations the loss is 2.29885, the accuracy is 0.14
# training! after 3100 iterations the loss is 2.29923, the accuracy is 0.148438
# ###################################
# validation! after 3200 iterations the loss is 2.29867, the accuracy is 0.1404
# training! after 3200 iterations the loss is 2.30221, the accuracy is 0.148438
# ###################################
# validation! after 3300 iterations the loss is 2.29852, the accuracy is 0.141
# training! after 3300 iterations the loss is 2.2957, the accuracy is 0.164062
# ###################################
# validation! after 3400 iterations the loss is 2.29837, the accuracy is 0.1428
# training! after 3400 iterations the loss is 2.30019, the accuracy is 0.117188
# ###################################
# validation! after 3500 iterations the loss is 2.29823, the accuracy is 0.144
# training! after 3500 iterations the loss is 2.29839, the accuracy is 0.140625
# ###################################
# validation! after 3600 iterations the loss is 2.29807, the accuracy is 0.1448
# training! after 3600 iterations the loss is 2.29556, the accuracy is 0.21875
# ###################################
# validation! after 3700 iterations the loss is 2.29792, the accuracy is 0.148
# training! after 3700 iterations the loss is 2.29221, the accuracy is 0.21875
# ###################################
# validation! after 3800 iterations the loss is 2.29778, the accuracy is 0.1482
# training! after 3800 iterations the loss is 2.29649, the accuracy is 0.21875
# ###################################
# validation! after 3900 iterations the loss is 2.29765, the accuracy is 0.148
# training! after 3900 iterations the loss is 2.2994, the accuracy is 0.117188
# ###################################
# validation! after 4000 iterations the loss is 2.29748, the accuracy is 0.1482
# training! after 4000 iterations the loss is 2.29577, the accuracy is 0.15625
# ###################################
# validation! after 4100 iterations the loss is 2.29733, the accuracy is 0.147
# training! after 4100 iterations the loss is 2.29631, the accuracy is 0.1875
# ###################################
# validation! after 4200 iterations the loss is 2.29718, the accuracy is 0.1462
# training! after 4200 iterations the loss is 2.29675, the accuracy is 0.117188
# ###################################
# validation! after 4300 iterations the loss is 2.29706, the accuracy is 0.1454
# training! after 4300 iterations the loss is 2.30052, the accuracy is 0.132812
# ###################################
# validation! after 4400 iterations the loss is 2.29691, the accuracy is 0.1446
# training! after 4400 iterations the loss is 2.29648, the accuracy is 0.109375
# ###################################
# validation! after 4500 iterations the loss is 2.29677, the accuracy is 0.1432
# training! after 4500 iterations the loss is 2.2993, the accuracy is 0.09375
# ###################################
# validation! after 4600 iterations the loss is 2.29664, the accuracy is 0.1436
# training! after 4600 iterations the loss is 2.28951, the accuracy is 0.203125
# ###################################
# validation! after 4700 iterations the loss is 2.2965, the accuracy is 0.142
# training! after 4700 iterations the loss is 2.29078, the accuracy is 0.171875
# ###################################
# validation! after 4800 iterations the loss is 2.29637, the accuracy is 0.14
# training! after 4800 iterations the loss is 2.29588, the accuracy is 0.132812
# ###################################
# validation! after 4900 iterations the loss is 2.29624, the accuracy is 0.138
# training! after 4900 iterations the loss is 2.29962, the accuracy is 0.148438
# ###################################
# validation! after 5000 iterations the loss is 2.29611, the accuracy is 0.138
# training! after 5000 iterations the loss is 2.29821, the accuracy is 0.132812
# ###################################
# validation! after 5100 iterations the loss is 2.29599, the accuracy is 0.137
# training! after 5100 iterations the loss is 2.29469, the accuracy is 0.15625
# ###################################
# validation! after 5200 iterations the loss is 2.29585, the accuracy is 0.1338
# training! after 5200 iterations the loss is 2.29866, the accuracy is 0.0859375
# ###################################
# validation! after 5300 iterations the loss is 2.29572, the accuracy is 0.1334
# training! after 5300 iterations the loss is 2.29295, the accuracy is 0.148438
# ###################################
# validation! after 5400 iterations the loss is 2.29559, the accuracy is 0.1318
# training! after 5400 iterations the loss is 2.29589, the accuracy is 0.171875
# ###################################
# validation! after 5500 iterations the loss is 2.29545, the accuracy is 0.1338
# training! after 5500 iterations the loss is 2.30066, the accuracy is 0.0859375
# ###################################
# validation! after 5600 iterations the loss is 2.29534, the accuracy is 0.1332
# training! after 5600 iterations the loss is 2.29662, the accuracy is 0.109375
# ###################################
# validation! after 5700 iterations the loss is 2.29521, the accuracy is 0.1342
# training! after 5700 iterations the loss is 2.29256, the accuracy is 0.132812
# ###################################
# validation! after 5800 iterations the loss is 2.29508, the accuracy is 0.133
# training! after 5800 iterations the loss is 2.29449, the accuracy is 0.101562
# ###################################
# validation! after 5900 iterations the loss is 2.29496, the accuracy is 0.132
# training! after 5900 iterations the loss is 2.29345, the accuracy is 0.132812
# ###################################
# validation! after 6000 iterations the loss is 2.29483, the accuracy is 0.1322
# training! after 6000 iterations the loss is 2.29415, the accuracy is 0.125
# ###################################
# validation! after 6100 iterations the loss is 2.29471, the accuracy is 0.1322
# training! after 6100 iterations the loss is 2.28989, the accuracy is 0.148438
# ###################################
# validation! after 6200 iterations the loss is 2.29459, the accuracy is 0.129
# training! after 6200 iterations the loss is 2.29816, the accuracy is 0.109375
# ###################################
# validation! after 6300 iterations the loss is 2.29446, the accuracy is 0.1286
# training! after 6300 iterations the loss is 2.28839, the accuracy is 0.132812
# ###################################
# validation! after 6400 iterations the loss is 2.29433, the accuracy is 0.1276
# training! after 6400 iterations the loss is 2.29028, the accuracy is 0.132812
# ###################################
# validation! after 6500 iterations the loss is 2.29419, the accuracy is 0.1276
# training! after 6500 iterations the loss is 2.2899, the accuracy is 0.148438
# ###################################
# validation! after 6600 iterations the loss is 2.29407, the accuracy is 0.1256
# training! after 6600 iterations the loss is 2.29445, the accuracy is 0.109375
# ###################################
# validation! after 6700 iterations the loss is 2.29395, the accuracy is 0.124
# training! after 6700 iterations the loss is 2.28965, the accuracy is 0.15625
# ###################################
# validation! after 6800 iterations the loss is 2.29382, the accuracy is 0.1234
# training! after 6800 iterations the loss is 2.29597, the accuracy is 0.125
# ###################################
# validation! after 6900 iterations the loss is 2.2937, the accuracy is 0.1228
# training! after 6900 iterations the loss is 2.30058, the accuracy is 0.0703125
# ###################################
# validation! after 7000 iterations the loss is 2.29358, the accuracy is 0.1204
# training! after 7000 iterations the loss is 2.29146, the accuracy is 0.117188
# ###################################
# validation! after 7100 iterations the loss is 2.29346, the accuracy is 0.12
# training! after 7100 iterations the loss is 2.29688, the accuracy is 0.117188
# ###################################
# validation! after 7200 iterations the loss is 2.29334, the accuracy is 0.1192
# training! after 7200 iterations the loss is 2.29025, the accuracy is 0.1875
# ###################################
# validation! after 7300 iterations the loss is 2.29323, the accuracy is 0.1194
# training! after 7300 iterations the loss is 2.29408, the accuracy is 0.117188
# ###################################
# validation! after 7400 iterations the loss is 2.2931, the accuracy is 0.1184
# training! after 7400 iterations the loss is 2.28833, the accuracy is 0.132812
# ###################################
# validation! after 7500 iterations the loss is 2.29298, the accuracy is 0.1176
# training! after 7500 iterations the loss is 2.29062, the accuracy is 0.109375
# ###################################
# validation! after 7600 iterations the loss is 2.29286, the accuracy is 0.117
# training! after 7600 iterations the loss is 2.29556, the accuracy is 0.101562
# ###################################
# validation! after 7700 iterations the loss is 2.29275, the accuracy is 0.1172
# training! after 7700 iterations the loss is 2.28714, the accuracy is 0.132812
# ###################################
# validation! after 7800 iterations the loss is 2.29261, the accuracy is 0.1152
# training! after 7800 iterations the loss is 2.29313, the accuracy is 0.0859375
# ###################################
# validation! after 7900 iterations the loss is 2.29249, the accuracy is 0.1154
# training! after 7900 iterations the loss is 2.28524, the accuracy is 0.164062
# ###################################
# validation! after 8000 iterations the loss is 2.29238, the accuracy is 0.115
# training! after 8000 iterations the loss is 2.29148, the accuracy is 0.101562
# ###################################
# validation! after 8100 iterations the loss is 2.29226, the accuracy is 0.1156
# training! after 8100 iterations the loss is 2.28371, the accuracy is 0.140625
# ###################################
# validation! after 8200 iterations the loss is 2.29215, the accuracy is 0.1152
# training! after 8200 iterations the loss is 2.28562, the accuracy is 0.171875
# ###################################
# validation! after 8300 iterations the loss is 2.29203, the accuracy is 0.1152
# training! after 8300 iterations the loss is 2.28841, the accuracy is 0.132812
# ###################################
# validation! after 8400 iterations the loss is 2.29192, the accuracy is 0.1152
# training! after 8400 iterations the loss is 2.2859, the accuracy is 0.148438
# ###################################
# validation! after 8500 iterations the loss is 2.2918, the accuracy is 0.115
# training! after 8500 iterations the loss is 2.29047, the accuracy is 0.101562
# ###################################
# validation! after 8600 iterations the loss is 2.29169, the accuracy is 0.1146
# training! after 8600 iterations the loss is 2.28859, the accuracy is 0.171875
# ###################################
# validation! after 8700 iterations the loss is 2.29156, the accuracy is 0.1146
# training! after 8700 iterations the loss is 2.28902, the accuracy is 0.109375
# ###################################
# validation! after 8800 iterations the loss is 2.29145, the accuracy is 0.1138
# training! after 8800 iterations the loss is 2.28114, the accuracy is 0.132812
# ###################################
# validation! after 8900 iterations the loss is 2.29133, the accuracy is 0.1138
# training! after 8900 iterations the loss is 2.29019, the accuracy is 0.125
# ###################################
# validation! after 9000 iterations the loss is 2.29122, the accuracy is 0.113
# training! after 9000 iterations the loss is 2.28936, the accuracy is 0.125
# ###################################
# validation! after 9100 iterations the loss is 2.29109, the accuracy is 0.1138
# training! after 9100 iterations the loss is 2.28543, the accuracy is 0.148438
# ###################################
# validation! after 9200 iterations the loss is 2.29098, the accuracy is 0.1136
# training! after 9200 iterations the loss is 2.29104, the accuracy is 0.125
# ###################################
# validation! after 9300 iterations the loss is 2.29087, the accuracy is 0.113
# training! after 9300 iterations the loss is 2.28283, the accuracy is 0.148438
# ###################################
# validation! after 9400 iterations the loss is 2.29076, the accuracy is 0.1124
# training! after 9400 iterations the loss is 2.29443, the accuracy is 0.09375
# ###################################
# validation! after 9500 iterations the loss is 2.29064, the accuracy is 0.1118
# training! after 9500 iterations the loss is 2.28482, the accuracy is 0.140625
# ###################################
# validation! after 9600 iterations the loss is 2.29052, the accuracy is 0.1124
# training! after 9600 iterations the loss is 2.29206, the accuracy is 0.101562
# ###################################
# validation! after 9700 iterations the loss is 2.2904, the accuracy is 0.1124
# training! after 9700 iterations the loss is 2.28127, the accuracy is 0.140625
# ###################################
# validation! after 9800 iterations the loss is 2.29028, the accuracy is 0.1112
# training! after 9800 iterations the loss is 2.28739, the accuracy is 0.0859375
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-0ca68db11ea9> in <module>()
# ----> 1 train(X_train, y_train, X_validation, y_validation, iteration)
#
# <ipython-input-13-8a0f7afc3011> in train(X_train, y_train, X_validation, y_validation, iteration)
#       7         for step in range(iteration):
#       8             X_batch, y_batch = get_batch(X_train, y_train, batch_size)
# ----> 9             sess.run(optimizer, feed_dict={X: X_batch, y:y_batch, dropout_rate:0.3, training:True})
#      10
#      11             if step % 100 == 0:
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /usr/lib/python3.4/dist-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
